# %%
# !pip install transformers
# !pip install sentencepiece

# %% [markdown]
# # **T5_BASE F1_Score**

# %%
import torch
import transformers
from transformers import T5Tokenizer, T5ForConditionalGeneration
from sklearn.metrics import f1_score, precision_score, recall_score

# set up the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# load the pretrained model and tokenizer
model = T5ForConditionalGeneration.from_pretrained("t5-base").to(device)
tokenizer = T5Tokenizer.from_pretrained("t5-base")

# define the function to generate answers
def generate_answer(question, context):
    input_str = "question: " + question + " context: " + context #+ " </s>"
    input_ids = tokenizer.encode(input_str, return_tensors="pt").to(device)
    outputs = model.generate(input_ids)
    # print("Output")
    # print(tokenizer.decode(outputs[0]))
    tem = tokenizer.decode(outputs[0])
    ans = ""
    n = len(tem)
    f = True
    for c in range(0,n):
      if tem[c]=='<':
        f = False
      elif tem[c]=='>':
        f = True
      else:
        if f==True:
          ans = ans + tem[c]
    print(ans)
    return ans
    # return tokenizer.decode(outputs[0])

# define the function to calculate F1 score
def calculate_f1_score(true_labels, predicted_labels):
    return f1_score(true_labels, predicted_labels, average='weighted')

# example sentences
sentences = [
"187 and 188 are from same hypothetical_ancestor_ 1 .",
"379 and 380 are from same hypothetical_ancestor_ 2 .",
"378 and hypothetical_ancestor_2 are from same hypothetical_ancestor_ 3 .",
"361 and 362 are from same hypothetical_ancestor_ 4 .",
"hypothetical_ancestor_3 and hypothetical_ancestor_4 are from same hypothetical_ancestor_ 5 .",
"159 and 162 are from same hypothetical_ancestor_ 6 .",
"163 and hypothetical_ancestor_6 are from same hypothetical_ancestor_ 7 .",
"164 and hypothetical_ancestor_7 are from same hypothetical_ancestor_ 8 .",
"161 and hypothetical_ancestor_8 are from same hypothetical_ancestor_ 9 .",
"154 and 155 are from same hypothetical_ancestor_ 10 .",
"127 and hypothetical_ancestor_10 are from same hypothetical_ancestor_ 11 .",
"177 and 179 are from same hypothetical_ancestor_ 12 .",
"178 and hypothetical_ancestor_12 are from same hypothetical_ancestor_ 13 .",
"180 and hypothetical_ancestor_13 are from same hypothetical_ancestor_ 14 .",
"186 and hypothetical_ancestor_14 are from same hypothetical_ancestor_ 15 .",
"hypothetical_ancestor_11 and hypothetical_ancestor_15 are from same hypothetical_ancestor_ 16 .",
"153 and 156 are from same hypothetical_ancestor_ 17 .",
"143 and 471 are from same hypothetical_ancestor_ 18 .",
"145 and hypothetical_ancestor_18 are from same hypothetical_ancestor_ 19 .",
"149 and hypothetical_ancestor_19 are from same hypothetical_ancestor_ 20 .",
"139 and 140 are from same hypothetical_ancestor_ 21 .",
"147 and hypothetical_ancestor_21 are from same hypothetical_ancestor_ 22 .",
"142 and 151 are from same hypothetical_ancestor_ 23 .",
"152 and hypothetical_ancestor_23 are from same hypothetical_ancestor_ 24 .",
"150 and hypothetical_ancestor_24 are from same hypothetical_ancestor_ 25 .",
"158 and hypothetical_ancestor_25 are from same hypothetical_ancestor_ 26 .",
"hypothetical_ancestor_22 and hypothetical_ancestor_26 are from same hypothetical_ancestor_ 27 .",
"146 and hypothetical_ancestor_27 are from same hypothetical_ancestor_ 28 .",
"hypothetical_ancestor_20 and hypothetical_ancestor_28 are from same hypothetical_ancestor_ 29 .",
"144 and hypothetical_ancestor_29 are from same hypothetical_ancestor_ 30 .",
"hypothetical_ancestor_17 and hypothetical_ancestor_30 are from same hypothetical_ancestor_ 31 .",
"141 and 165 are from same hypothetical_ancestor_ 32 .",
"176 and hypothetical_ancestor_32 are from same hypothetical_ancestor_ 33 .",
"168 and hypothetical_ancestor_33 are from same hypothetical_ancestor_ 34 .",
"hypothetical_ancestor_31 and hypothetical_ancestor_34 are from same hypothetical_ancestor_ 35 .",
"148 and 174 are from same hypothetical_ancestor_ 36 .",
"hypothetical_ancestor_35 and hypothetical_ancestor_36 are from same hypothetical_ancestor_ 37 .",
"131 and 130 are from same hypothetical_ancestor_ 38 .",
"135 and 133 are from same hypothetical_ancestor_ 39 .",
"hypothetical_ancestor_38 and hypothetical_ancestor_39 are from same hypothetical_ancestor_ 40 .",
"132 and hypothetical_ancestor_40 are from same hypothetical_ancestor_ 41 .",
"134 and hypothetical_ancestor_41 are from same hypothetical_ancestor_ 42 .",
"136 and hypothetical_ancestor_42 are from same hypothetical_ancestor_ 43 .",
"427 and 428 are from same hypothetical_ancestor_ 44 .",
"429 and hypothetical_ancestor_44 are from same hypothetical_ancestor_ 45 .",
"423 and 426 are from same hypothetical_ancestor_ 46 .",
"424 and hypothetical_ancestor_46 are from same hypothetical_ancestor_ 47 .",
"425 and hypothetical_ancestor_47 are from same hypothetical_ancestor_ 48 .",
"hypothetical_ancestor_45 and hypothetical_ancestor_48 are from same hypothetical_ancestor_ 49 .",
"hypothetical_ancestor_43 and hypothetical_ancestor_49 are from same hypothetical_ancestor_ 50 .",
"138 and hypothetical_ancestor_50 are from same hypothetical_ancestor_ 51 .",
"166 and 280 are from same hypothetical_ancestor_ 52 .",
"175 and 171 are from same hypothetical_ancestor_ 53 .",
"hypothetical_ancestor_52 and hypothetical_ancestor_53 are from same hypothetical_ancestor_ 54 .",
"453 and 456 are from same hypothetical_ancestor_ 55 .",
"462 and 463 are from same hypothetical_ancestor_ 56 .",
"458 and hypothetical_ancestor_56 are from same hypothetical_ancestor_ 57 .",
"457 and 461 are from same hypothetical_ancestor_ 58 .",
"459 and hypothetical_ancestor_58 are from same hypothetical_ancestor_ 59 .",
"hypothetical_ancestor_57 and hypothetical_ancestor_59 are from same hypothetical_ancestor_ 60 .",
"454 and hypothetical_ancestor_60 are from same hypothetical_ancestor_ 61 .",
"hypothetical_ancestor_55 and hypothetical_ancestor_61 are from same hypothetical_ancestor_ 62 .",
"455 and 460 are from same hypothetical_ancestor_ 63 .",
"350 and hypothetical_ancestor_63 are from same hypothetical_ancestor_ 64 .",
"349 and 351 are from same hypothetical_ancestor_ 65 .",
"352 and hypothetical_ancestor_65 are from same hypothetical_ancestor_ 66 .",
"hypothetical_ancestor_64 and hypothetical_ancestor_66 are from same hypothetical_ancestor_ 67 .",
"330 and 334 are from same hypothetical_ancestor_ 68 .",
"331 and 335 are from same hypothetical_ancestor_ 69 .",
"332 and hypothetical_ancestor_69 are from same hypothetical_ancestor_ 70 .",
"hypothetical_ancestor_68 and hypothetical_ancestor_70 are from same hypothetical_ancestor_ 71 .",
"329 and 333 are from same hypothetical_ancestor_ 72 .",
"hypothetical_ancestor_71 and hypothetical_ancestor_72 are from same hypothetical_ancestor_ 73 .",
"hypothetical_ancestor_67 and hypothetical_ancestor_73 are from same hypothetical_ancestor_ 74 .",
"326 and 328 are from same hypothetical_ancestor_ 75 .",
"327 and hypothetical_ancestor_75 are from same hypothetical_ancestor_ 76 .",
"342 and 357 are from same hypothetical_ancestor_ 77 .",
"hypothetical_ancestor_76 and hypothetical_ancestor_77 are from same hypothetical_ancestor_ 78 .",
"343 and 344 are from same hypothetical_ancestor_ 79 .",
"345 and 347 are from same hypothetical_ancestor_ 80 .",
"346 and hypothetical_ancestor_80 are from same hypothetical_ancestor_ 81 .",
"hypothetical_ancestor_79 and hypothetical_ancestor_81 are from same hypothetical_ancestor_ 82 .",
"262 and 263 are from same hypothetical_ancestor_ 83 .",
"264 and hypothetical_ancestor_83 are from same hypothetical_ancestor_ 84 .",
"340 and hypothetical_ancestor_84 are from same hypothetical_ancestor_ 85 .",
"341 and hypothetical_ancestor_85 are from same hypothetical_ancestor_ 86 .",
"338 and 336 are from same hypothetical_ancestor_ 87 .",
"339 and hypothetical_ancestor_87 are from same hypothetical_ancestor_ 88 .",
"hypothetical_ancestor_88 and 337 are from same hypothetical_ancestor_ 89 .",
"348 and hypothetical_ancestor_89 are from same hypothetical_ancestor_ 90 .",
"358 and 359 are from same hypothetical_ancestor_ 91 .",
"353 and hypothetical_ancestor_91 are from same hypothetical_ancestor_ 92 .",
"354 and 356 are from same hypothetical_ancestor_ 93 .",
"360 and hypothetical_ancestor_93 are from same hypothetical_ancestor_ 94 .",
"hypothetical_ancestor_92 and hypothetical_ancestor_94 are from same hypothetical_ancestor_ 95 .",
"355 and hypothetical_ancestor_95 are from same hypothetical_ancestor_ 96 .",
"hypothetical_ancestor_90 and hypothetical_ancestor_96 are from same hypothetical_ancestor_ 97 .",
"hypothetical_ancestor_86 and hypothetical_ancestor_97 are from same hypothetical_ancestor_ 98 .",
"hypothetical_ancestor_82 and hypothetical_ancestor_98 are from same hypothetical_ancestor_ 99 .",
"hypothetical_ancestor_78 and hypothetical_ancestor_99 are from same hypothetical_ancestor_ 100 .",
"hypothetical_ancestor_74 and hypothetical_ancestor_100 are from same hypothetical_ancestor_ 101 .",
"hypothetical_ancestor_62 and hypothetical_ancestor_101 are from same hypothetical_ancestor_ 102 .",
"hypothetical_ancestor_54 and hypothetical_ancestor_102 are from same hypothetical_ancestor_ 103 .",
"367 and 369 are from same hypothetical_ancestor_ 104 .",
"366 and hypothetical_ancestor_104 are from same hypothetical_ancestor_ 105 .",
"170 and 173 are from same hypothetical_ancestor_ 106 .",
"365 and hypothetical_ancestor_106 are from same hypothetical_ancestor_ 107 .",
"hypothetical_ancestor_105 and hypothetical_ancestor_107 are from same hypothetical_ancestor_ 108 .",
"368 and hypothetical_ancestor_108 are from same hypothetical_ancestor_ 109 .",
"213 and 214 are from same hypothetical_ancestor_ 110 .",
"411 and 412 are from same hypothetical_ancestor_ 111 .",
"409 and 410 are from same hypothetical_ancestor_ 112 .",
"hypothetical_ancestor_111 and hypothetical_ancestor_112 are from same hypothetical_ancestor_ 113 .",
"294 and hypothetical_ancestor_113 are from same hypothetical_ancestor_ 114 .",
"452 and hypothetical_ancestor_114 are from same hypothetical_ancestor_ 115 .",
"hypothetical_ancestor_110 and hypothetical_ancestor_115 are from same hypothetical_ancestor_ 116 .",
"169 and hypothetical_ancestor_116 are from same hypothetical_ancestor_ 117 .",
"172 and hypothetical_ancestor_117 are from same hypothetical_ancestor_ 118 .",
"293 and hypothetical_ancestor_118 are from same hypothetical_ancestor_ 119 .",
"hypothetical_ancestor_109 and hypothetical_ancestor_119 are from same hypothetical_ancestor_ 120 .",
"207 and 208 are from same hypothetical_ancestor_ 121 .",
"384 and hypothetical_ancestor_121 are from same hypothetical_ancestor_ 122 .",
"404 and 184 are from same hypothetical_ancestor_ 123 .",
"292 and hypothetical_ancestor_123 are from same hypothetical_ancestor_ 124 .",
"181 and hypothetical_ancestor_124 are from same hypothetical_ancestor_ 125 .",
"395 and 397 are from same hypothetical_ancestor_ 126 .",
"396 and hypothetical_ancestor_126 are from same hypothetical_ancestor_ 127 .",
"386 and hypothetical_ancestor_127 are from same hypothetical_ancestor_ 128 .",
"221 and 223 are from same hypothetical_ancestor_ 129 .",
"267 and 215 are from same hypothetical_ancestor_ 130 .",
"hypothetical_ancestor_129 and hypothetical_ancestor_130 are from same hypothetical_ancestor_ 131 .",
"222 and hypothetical_ancestor_131 are from same hypothetical_ancestor_ 132 .",
"231 and hypothetical_ancestor_132 are from same hypothetical_ancestor_ 133 .",
"233 and hypothetical_ancestor_133 are from same hypothetical_ancestor_ 134 .",
"394 and hypothetical_ancestor_134 are from same hypothetical_ancestor_ 135 .",
"392 and hypothetical_ancestor_135 are from same hypothetical_ancestor_ 136 .",
"393 and hypothetical_ancestor_136 are from same hypothetical_ancestor_ 137 .",
"hypothetical_ancestor_128 and hypothetical_ancestor_137 are from same hypothetical_ancestor_ 138 .",
"398 and hypothetical_ancestor_138 are from same hypothetical_ancestor_ 139 .",
"391 and hypothetical_ancestor_139 are from same hypothetical_ancestor_ 140 .",
"276 and 390 are from same hypothetical_ancestor_ 141 .",
"382 and hypothetical_ancestor_141 are from same hypothetical_ancestor_ 142 .",
"381 and 383 are from same hypothetical_ancestor_ 143 .",
"415 and 413 are from same hypothetical_ancestor_ 144 .",
"414 and hypothetical_ancestor_144 are from same hypothetical_ancestor_ 145 .",
"418 and hypothetical_ancestor_145 are from same hypothetical_ancestor_ 146 .",
"385 and 399 are from same hypothetical_ancestor_ 147 .",
"400 and 402 are from same hypothetical_ancestor_ 148 .",
"401 and hypothetical_ancestor_148 are from same hypothetical_ancestor_ 149 .",
"403 and hypothetical_ancestor_149 are from same hypothetical_ancestor_ 150 .",
"389 and 388 are from same hypothetical_ancestor_ 151 .",
"hypothetical_ancestor_150 and hypothetical_ancestor_151 are from same hypothetical_ancestor_ 152 .",
"387 and hypothetical_ancestor_152 are from same hypothetical_ancestor_ 153 .",
"hypothetical_ancestor_147 and hypothetical_ancestor_153 are from same hypothetical_ancestor_ 154 .",
"hypothetical_ancestor_146 and hypothetical_ancestor_154 are from same hypothetical_ancestor_ 155 .",
"hypothetical_ancestor_143 and hypothetical_ancestor_155 are from same hypothetical_ancestor_ 156 .",
"279 and hypothetical_ancestor_156 are from same hypothetical_ancestor_ 157 .",
"hypothetical_ancestor_142 and hypothetical_ancestor_157 are from same hypothetical_ancestor_ 158 .",
"hypothetical_ancestor_140 and hypothetical_ancestor_158 are from same hypothetical_ancestor_ 159 .",
"268 and 273 are from same hypothetical_ancestor_ 160 .",
"274 and hypothetical_ancestor_160 are from same hypothetical_ancestor_ 161 .",
"216 and 219 are from same hypothetical_ancestor_ 162 .",
"hypothetical_ancestor_162 and 217 are from same hypothetical_ancestor_ 163 .",
"218 and hypothetical_ancestor_163 are from same hypothetical_ancestor_ 164 .",
"hypothetical_ancestor_161 and hypothetical_ancestor_164 are from same hypothetical_ancestor_ 165 .",
"224 and 228 are from same hypothetical_ancestor_ 166 .",
"hypothetical_ancestor_166 and 226 are from same hypothetical_ancestor_ 167 .",
"hypothetical_ancestor_167 and 225 are from same hypothetical_ancestor_ 168 .",
"227 and hypothetical_ancestor_168 are from same hypothetical_ancestor_ 169 .",
"277 and hypothetical_ancestor_169 are from same hypothetical_ancestor_ 170 .",
"370 and 371 are from same hypothetical_ancestor_ 171 .",
"372 and 373 are from same hypothetical_ancestor_ 172 .",
"hypothetical_ancestor_171 and hypothetical_ancestor_172 are from same hypothetical_ancestor_ 173 .",
"374 and hypothetical_ancestor_173 are from same hypothetical_ancestor_ 174 .",
"283 and 288 are from same hypothetical_ancestor_ 175 .",
"286 and hypothetical_ancestor_175 are from same hypothetical_ancestor_ 176 .",
"284 and hypothetical_ancestor_176 are from same hypothetical_ancestor_ 177 .",
"253 and hypothetical_ancestor_177 are from same hypothetical_ancestor_ 178 .",
"287 and hypothetical_ancestor_178 are from same hypothetical_ancestor_ 179 .",
"290 and hypothetical_ancestor_179 are from same hypothetical_ancestor_ 180 .",
"285 and hypothetical_ancestor_180 are from same hypothetical_ancestor_ 181 .",
"289 and hypothetical_ancestor_181 are from same hypothetical_ancestor_ 182 .",
"266 and hypothetical_ancestor_182 are from same hypothetical_ancestor_ 183 .",
"255 and 256 are from same hypothetical_ancestor_ 184 .",
"252 and hypothetical_ancestor_184 are from same hypothetical_ancestor_ 185 .",
"248 and 249 are from same hypothetical_ancestor_ 186 .",
"271 and hypothetical_ancestor_186 are from same hypothetical_ancestor_ 187 .",
"241 and hypothetical_ancestor_187 are from same hypothetical_ancestor_ 188 .",
"247 and hypothetical_ancestor_188 are from same hypothetical_ancestor_ 189 .",
"245 and hypothetical_ancestor_189 are from same hypothetical_ancestor_ 190 .",
"278 and hypothetical_ancestor_190 are from same hypothetical_ancestor_ 191 .",
"246 and hypothetical_ancestor_191 are from same hypothetical_ancestor_ 192 .",
"275 and hypothetical_ancestor_192 are from same hypothetical_ancestor_ 193 .",
"250 and hypothetical_ancestor_193 are from same hypothetical_ancestor_ 194 .",
"254 and hypothetical_ancestor_194 are from same hypothetical_ancestor_ 195 .",
"hypothetical_ancestor_185 and hypothetical_ancestor_195 are from same hypothetical_ancestor_ 196 .",
"hypothetical_ancestor_183 and hypothetical_ancestor_196 are from same hypothetical_ancestor_ 197 .",
"hypothetical_ancestor_174 and hypothetical_ancestor_197 are from same hypothetical_ancestor_ 198 .",
"291 and hypothetical_ancestor_198 are from same hypothetical_ancestor_ 199 .",
"203 and hypothetical_ancestor_199 are from same hypothetical_ancestor_ 200 .",
"281 and 282 are from same hypothetical_ancestor_ 201 .",
"212 and 211 are from same hypothetical_ancestor_ 202 .",
"210 and hypothetical_ancestor_202 are from same hypothetical_ancestor_ 203 .",
"hypothetical_ancestor_201 and hypothetical_ancestor_203 are from same hypothetical_ancestor_ 204 .",
"420 and 421 are from same hypothetical_ancestor_ 205 .",
"417 and 416 are from same hypothetical_ancestor_ 206 .",
"422 and hypothetical_ancestor_206 are from same hypothetical_ancestor_ 207 .",
"419 and hypothetical_ancestor_207 are from same hypothetical_ancestor_ 208 .",
"hypothetical_ancestor_205 and hypothetical_ancestor_208 are from same hypothetical_ancestor_ 209 .",
"hypothetical_ancestor_204 and hypothetical_ancestor_209 are from same hypothetical_ancestor_ 210 .",
"251 and 272 are from same hypothetical_ancestor_ 211 .",
"243 and 261 are from same hypothetical_ancestor_ 212 .",
"265 and 377 are from same hypothetical_ancestor_ 213 .",
"258 and 260 are from same hypothetical_ancestor_ 214 .",
"257 and hypothetical_ancestor_214 are from same hypothetical_ancestor_ 215 .",
"376 and 375 are from same hypothetical_ancestor_ 216 .",
"hypothetical_ancestor_215 and hypothetical_ancestor_216 are from same hypothetical_ancestor_ 217 .",
"hypothetical_ancestor_213 and hypothetical_ancestor_217 are from same hypothetical_ancestor_ 218 .",
"hypothetical_ancestor_212 and hypothetical_ancestor_218 are from same hypothetical_ancestor_ 219 .",
"hypothetical_ancestor_211 and hypothetical_ancestor_219 are from same hypothetical_ancestor_ 220 .",
"209 and 230 are from same hypothetical_ancestor_ 221 .",
"269 and 232 are from same hypothetical_ancestor_ 222 .",
"hypothetical_ancestor_221 and hypothetical_ancestor_222 are from same hypothetical_ancestor_ 223 .",
"229 and 238 are from same hypothetical_ancestor_ 224 .",
"234 and 242 are from same hypothetical_ancestor_ 225 .",
"236 and hypothetical_ancestor_225 are from same hypothetical_ancestor_ 226 .",
"hypothetical_ancestor_224 and hypothetical_ancestor_226 are from same hypothetical_ancestor_ 227 .",
"hypothetical_ancestor_223 and hypothetical_ancestor_227 are from same hypothetical_ancestor_ 228 .",
"237 and hypothetical_ancestor_228 are from same hypothetical_ancestor_ 229 .",
"239 and hypothetical_ancestor_229 are from same hypothetical_ancestor_ 230 .",
"244 and hypothetical_ancestor_230 are from same hypothetical_ancestor_ 231 .",
"235 and hypothetical_ancestor_231 are from same hypothetical_ancestor_ 232 .",
"259 and 472 are from same hypothetical_ancestor_ 233 .",
"hypothetical_ancestor_232 and hypothetical_ancestor_233 are from same hypothetical_ancestor_ 234 .",
"hypothetical_ancestor_234 and 240 are from same hypothetical_ancestor_ 235 .",
"hypothetical_ancestor_220 and hypothetical_ancestor_235 are from same hypothetical_ancestor_ 236 .",
"hypothetical_ancestor_210 and hypothetical_ancestor_236 are from same hypothetical_ancestor_ 237 .",
"hypothetical_ancestor_200 and hypothetical_ancestor_237 are from same hypothetical_ancestor_ 238 .",
"hypothetical_ancestor_170 and hypothetical_ancestor_238 are from same hypothetical_ancestor_ 239 .",
"hypothetical_ancestor_165 and hypothetical_ancestor_239 are from same hypothetical_ancestor_ 240 .",
"hypothetical_ancestor_159 and hypothetical_ancestor_240 are from same hypothetical_ancestor_ 241 .",
"270 and hypothetical_ancestor_241 are from same hypothetical_ancestor_ 242 .",
"220 and hypothetical_ancestor_242 are from same hypothetical_ancestor_ 243 .",
"hypothetical_ancestor_125 and hypothetical_ancestor_243 are from same hypothetical_ancestor_ 244 .",
"hypothetical_ancestor_122 and hypothetical_ancestor_244 are from same hypothetical_ancestor_ 245 .",
"hypothetical_ancestor_120 and hypothetical_ancestor_245 are from same hypothetical_ancestor_ 246 .",
"hypothetical_ancestor_103 and hypothetical_ancestor_246 are from same hypothetical_ancestor_ 247 .",
"hypothetical_ancestor_51 and hypothetical_ancestor_247 are from same hypothetical_ancestor_ 248 .",
"408 and hypothetical_ancestor_248 are from same hypothetical_ancestor_ 249 .",
"hypothetical_ancestor_37 and hypothetical_ancestor_249 are from same hypothetical_ancestor_ 250 .",
"hypothetical_ancestor_16 and hypothetical_ancestor_250 are from same hypothetical_ancestor_ 251 .",
"129 and hypothetical_ancestor_251 are from same hypothetical_ancestor_ 252 .",
"hypothetical_ancestor_9 and hypothetical_ancestor_252 are from same hypothetical_ancestor_ 253 .",
"128 and hypothetical_ancestor_253 are from same hypothetical_ancestor_ 254 .",
"321 and 324 are from same hypothetical_ancestor_ 255 .",
"325 and hypothetical_ancestor_255 are from same hypothetical_ancestor_ 256 .",
"322 and hypothetical_ancestor_256 are from same hypothetical_ancestor_ 257 .",
"323 and hypothetical_ancestor_257 are from same hypothetical_ancestor_ 258 .",
"476 and 473 are from same hypothetical_ancestor_ 259 .",
"160 and hypothetical_ancestor_259 are from same hypothetical_ancestor_ 260 .",
"475 and 474 are from same hypothetical_ancestor_ 261 .",
"185 and hypothetical_ancestor_261 are from same hypothetical_ancestor_ 262 .",
"hypothetical_ancestor_260 and hypothetical_ancestor_262 are from same hypothetical_ancestor_ 263 .",
"hypothetical_ancestor_258 and hypothetical_ancestor_263 are from same hypothetical_ancestor_ 264 .",
"310 and 313 are from same hypothetical_ancestor_ 265 .",
"315 and 320 are from same hypothetical_ancestor_ 266 .",
"316 and 317 are from same hypothetical_ancestor_ 267 .",
"hypothetical_ancestor_266 and hypothetical_ancestor_267 are from same hypothetical_ancestor_ 268 .",
"314 and hypothetical_ancestor_268 are from same hypothetical_ancestor_ 269 .",
"309 and hypothetical_ancestor_269 are from same hypothetical_ancestor_ 270 .",
"hypothetical_ancestor_265 and hypothetical_ancestor_270 are from same hypothetical_ancestor_ 271 .",
"301 and 306 are from same hypothetical_ancestor_ 272 .",
"298 and hypothetical_ancestor_272 are from same hypothetical_ancestor_ 273 .",
"300 and hypothetical_ancestor_273 are from same hypothetical_ancestor_ 274 .",
"311 and hypothetical_ancestor_274 are from same hypothetical_ancestor_ 275 .",
"303 and hypothetical_ancestor_275 are from same hypothetical_ancestor_ 276 .",
"295 and hypothetical_ancestor_276 are from same hypothetical_ancestor_ 277 .",
"296 and hypothetical_ancestor_277 are from same hypothetical_ancestor_ 278 .",
"305 and 318 are from same hypothetical_ancestor_ 279 .",
"297 and hypothetical_ancestor_279 are from same hypothetical_ancestor_ 280 .",
"304 and hypothetical_ancestor_280 are from same hypothetical_ancestor_ 281 .",
"302 and 307 are from same hypothetical_ancestor_ 282 .",
"299 and hypothetical_ancestor_282 are from same hypothetical_ancestor_ 283 .",
"312 and hypothetical_ancestor_283 are from same hypothetical_ancestor_ 284 .",
"hypothetical_ancestor_281 and hypothetical_ancestor_284 are from same hypothetical_ancestor_ 285 .",
"308 and hypothetical_ancestor_285 are from same hypothetical_ancestor_ 286 .",
"319 and hypothetical_ancestor_286 are from same hypothetical_ancestor_ 287 .",
"hypothetical_ancestor_278 and hypothetical_ancestor_287 are from same hypothetical_ancestor_ 288 .",
"hypothetical_ancestor_271 and hypothetical_ancestor_288 are from same hypothetical_ancestor_ 289 .",
"hypothetical_ancestor_264 and hypothetical_ancestor_289 are from same hypothetical_ancestor_ 290 .",
"191 and 198 are from same hypothetical_ancestor_ 291 .",
"190 and 194 are from same hypothetical_ancestor_ 292 .",
"189 and 192 are from same hypothetical_ancestor_ 293 .",
"hypothetical_ancestor_292 and hypothetical_ancestor_293 are from same hypothetical_ancestor_ 294 .",
"196 and 197 are from same hypothetical_ancestor_ 295 .",
"195 and 201 are from same hypothetical_ancestor_ 296 .",
"202 and hypothetical_ancestor_296 are from same hypothetical_ancestor_ 297 .",
"hypothetical_ancestor_295 and hypothetical_ancestor_297 are from same hypothetical_ancestor_ 298 .",
"200 and hypothetical_ancestor_298 are from same hypothetical_ancestor_ 299 .",
"hypothetical_ancestor_294 and hypothetical_ancestor_299 are from same hypothetical_ancestor_ 300 .",
"193 and hypothetical_ancestor_300 are from same hypothetical_ancestor_ 301 .",
"hypothetical_ancestor_291 and hypothetical_ancestor_301 are from same hypothetical_ancestor_ 302 .",
"199 and hypothetical_ancestor_302 are from same hypothetical_ancestor_ 303 .",
"431 and 432 are from same hypothetical_ancestor_ 304 .",
"436 and 447 are from same hypothetical_ancestor_ 305 .",
"439 and 442 are from same hypothetical_ancestor_ 306 .",
"435 and hypothetical_ancestor_306 are from same hypothetical_ancestor_ 307 .",
"448 and hypothetical_ancestor_307 are from same hypothetical_ancestor_ 308 .",
"hypothetical_ancestor_305 and hypothetical_ancestor_308 are from same hypothetical_ancestor_ 309 .",
"433 and 441 are from same hypothetical_ancestor_ 310 .",
"437 and 440 are from same hypothetical_ancestor_ 311 .",
"443 and 449 are from same hypothetical_ancestor_ 312 .",
"450 and hypothetical_ancestor_312 are from same hypothetical_ancestor_ 313 .",
"445 and 446 are from same hypothetical_ancestor_ 314 .",
"451 and hypothetical_ancestor_314 are from same hypothetical_ancestor_ 315 .",
"438 and hypothetical_ancestor_315 are from same hypothetical_ancestor_ 316 .",
"hypothetical_ancestor_313 and hypothetical_ancestor_316 are from same hypothetical_ancestor_ 317 .",
"444 and hypothetical_ancestor_317 are from same hypothetical_ancestor_ 318 .",
"hypothetical_ancestor_311 and hypothetical_ancestor_318 are from same hypothetical_ancestor_ 319 .",
"hypothetical_ancestor_310 and hypothetical_ancestor_319 are from same hypothetical_ancestor_ 320 .",
"434 and hypothetical_ancestor_320 are from same hypothetical_ancestor_ 321 .",
"hypothetical_ancestor_309 and hypothetical_ancestor_321 are from same hypothetical_ancestor_ 322 .",
"hypothetical_ancestor_304 and hypothetical_ancestor_322 are from same hypothetical_ancestor_ 323 .",
"hypothetical_ancestor_303 and hypothetical_ancestor_323 are from same hypothetical_ancestor_ 324 .",
"hypothetical_ancestor_290 and hypothetical_ancestor_324 are from same hypothetical_ancestor_ 325 .",
"137 and 167 are from same hypothetical_ancestor_ 326 .",
"464 and 465 are from same hypothetical_ancestor_ 327 .",
"466 and 470 are from same hypothetical_ancestor_ 328 .",
"467 and hypothetical_ancestor_328 are from same hypothetical_ancestor_ 329 .",
"469 and hypothetical_ancestor_329 are from same hypothetical_ancestor_ 330 .",
"468 and hypothetical_ancestor_330 are from same hypothetical_ancestor_ 331 .",
"hypothetical_ancestor_327 and hypothetical_ancestor_331 are from same hypothetical_ancestor_ 332 .",
"182 and 183 are from same hypothetical_ancestor_ 333 .",
"120 and hypothetical_ancestor_333 are from same hypothetical_ancestor_ 334 .",
"112 and 117 are from same hypothetical_ancestor_ 335 .",
"113 and 116 are from same hypothetical_ancestor_ 336 .",
"114 and 118 are from same hypothetical_ancestor_ 337 .",
"hypothetical_ancestor_336 and hypothetical_ancestor_337 are from same hypothetical_ancestor_ 338 .",
"hypothetical_ancestor_335 and hypothetical_ancestor_338 are from same hypothetical_ancestor_ 339 .",
"115 and hypothetical_ancestor_339 are from same hypothetical_ancestor_ 340 .",
"123 and 125 are from same hypothetical_ancestor_ 341 .",
"124 and hypothetical_ancestor_341 are from same hypothetical_ancestor_ 342 .",
"126 and hypothetical_ancestor_342 are from same hypothetical_ancestor_ 343 .",
"119 and hypothetical_ancestor_343 are from same hypothetical_ancestor_ 344 .",
"121 and hypothetical_ancestor_344 are from same hypothetical_ancestor_ 345 .",
"hypothetical_ancestor_340 and hypothetical_ancestor_345 are from same hypothetical_ancestor_ 346 .",
"157 and hypothetical_ancestor_346 are from same hypothetical_ancestor_ 347 .",
"hypothetical_ancestor_334 and hypothetical_ancestor_347 are from same hypothetical_ancestor_ 348 .",
"204 and 205 are from same hypothetical_ancestor_ 349 .",
"364 and 206 are from same hypothetical_ancestor_ 350 .",
"407 and 405 are from same hypothetical_ancestor_ 351 .",
"406 and hypothetical_ancestor_351 are from same hypothetical_ancestor_ 352 .",
"hypothetical_ancestor_350 and hypothetical_ancestor_352 are from same hypothetical_ancestor_ 353 .",
"hypothetical_ancestor_349 and hypothetical_ancestor_353 are from same hypothetical_ancestor_ 354 .",
"122 and hypothetical_ancestor_354 are from same hypothetical_ancestor_ 355 .",
"105 and 100 are from same hypothetical_ancestor_ 356 .",
"102 and hypothetical_ancestor_356 are from same hypothetical_ancestor_ 357 .",
"92 and hypothetical_ancestor_357 are from same hypothetical_ancestor_ 358 .",
"88 and 101 are from same hypothetical_ancestor_ 359 .",
"75 and 85 are from same hypothetical_ancestor_ 360 .",
"82 and 106 are from same hypothetical_ancestor_ 361 .",
"hypothetical_ancestor_360 and hypothetical_ancestor_361 are from same hypothetical_ancestor_ 362 .",
"96 and hypothetical_ancestor_362 are from same hypothetical_ancestor_ 363 .",
"83 and 94 are from same hypothetical_ancestor_ 364 .",
"97 and 99 are from same hypothetical_ancestor_ 365 .",
"103 and 110 are from same hypothetical_ancestor_ 366 .",
"hypothetical_ancestor_365 and hypothetical_ancestor_366 are from same hypothetical_ancestor_ 367 .",
"104 and hypothetical_ancestor_367 are from same hypothetical_ancestor_ 368 .",
"91 and hypothetical_ancestor_368 are from same hypothetical_ancestor_ 369 .",
"hypothetical_ancestor_364 and hypothetical_ancestor_369 are from same hypothetical_ancestor_ 370 .",
"hypothetical_ancestor_363 and hypothetical_ancestor_370 are from same hypothetical_ancestor_ 371 .",
"109 and 84 are from same hypothetical_ancestor_ 372 .",
"98 and hypothetical_ancestor_372 are from same hypothetical_ancestor_ 373 .",
"89 and hypothetical_ancestor_373 are from same hypothetical_ancestor_ 374 .",
"86 and 111 are from same hypothetical_ancestor_ 375 .",
"90 and hypothetical_ancestor_375 are from same hypothetical_ancestor_ 376 .",
"95 and 107 are from same hypothetical_ancestor_ 377 .",
"108 and hypothetical_ancestor_377 are from same hypothetical_ancestor_ 378 .",
"93 and hypothetical_ancestor_378 are from same hypothetical_ancestor_ 379 .",
"hypothetical_ancestor_379 and 76 are from same hypothetical_ancestor_ 380 .",
"hypothetical_ancestor_376 and hypothetical_ancestor_380 are from same hypothetical_ancestor_ 381 .",
"hypothetical_ancestor_374 and hypothetical_ancestor_381 are from same hypothetical_ancestor_ 382 .",
"87 and hypothetical_ancestor_382 are from same hypothetical_ancestor_ 383 .",
"hypothetical_ancestor_371 and hypothetical_ancestor_383 are from same hypothetical_ancestor_ 384 .",
"hypothetical_ancestor_359 and hypothetical_ancestor_384 are from same hypothetical_ancestor_ 385 .",
"hypothetical_ancestor_358 and hypothetical_ancestor_385 are from same hypothetical_ancestor_ 386 .",
"80 and 79 are from same hypothetical_ancestor_ 387 .",
"78 and hypothetical_ancestor_387 are from same hypothetical_ancestor_ 388 .",
"81 and hypothetical_ancestor_388 are from same hypothetical_ancestor_ 389 .",
"69 and 33 are from same hypothetical_ancestor_ 390 .",
"hypothetical_ancestor_390 and 19 are from same hypothetical_ancestor_ 391 .",
"20 and 67 are from same hypothetical_ancestor_ 392 .",
"1 and 22 are from same hypothetical_ancestor_ 393 .",
"12 and 52 are from same hypothetical_ancestor_ 394 .",
"37 and 50 are from same hypothetical_ancestor_ 395 .",
"2 and 58 are from same hypothetical_ancestor_ 396 .",
"36 and 16 are from same hypothetical_ancestor_ 397 .",
"23 and 61 are from same hypothetical_ancestor_ 398 .",
"hypothetical_ancestor_397 and hypothetical_ancestor_398 are from same hypothetical_ancestor_ 399 .",
"25 and 30 are from same hypothetical_ancestor_ 400 .",
"hypothetical_ancestor_400 and 24 are from same hypothetical_ancestor_ 401 .",
"60 and hypothetical_ancestor_401 are from same hypothetical_ancestor_ 402 .",
"57 and 48 are from same hypothetical_ancestor_ 403 .",
"hypothetical_ancestor_403 and 17 are from same hypothetical_ancestor_ 404 .",
"hypothetical_ancestor_404 and 47 are from same hypothetical_ancestor_ 405 .",
"hypothetical_ancestor_402 and hypothetical_ancestor_405 are from same hypothetical_ancestor_ 406 .",
"32 and 44 are from same hypothetical_ancestor_ 407 .",
"14 and hypothetical_ancestor_407 are from same hypothetical_ancestor_ 408 .",
"4 and 31 are from same hypothetical_ancestor_ 409 .",
"hypothetical_ancestor_408 and hypothetical_ancestor_409 are from same hypothetical_ancestor_ 410 .",
"45 and 66 are from same hypothetical_ancestor_ 411 .",
"hypothetical_ancestor_410 and hypothetical_ancestor_411 are from same hypothetical_ancestor_ 412 .",
"hypothetical_ancestor_406 and hypothetical_ancestor_412 are from same hypothetical_ancestor_ 413 .",
"hypothetical_ancestor_399 and hypothetical_ancestor_413 are from same hypothetical_ancestor_ 414 .",
"18 and 63 are from same hypothetical_ancestor_ 415 .",
"7 and 41 are from same hypothetical_ancestor_ 416 .",
"65 and 70 are from same hypothetical_ancestor_ 417 .",
"10 and hypothetical_ancestor_417 are from same hypothetical_ancestor_ 418 .",
"15 and 74 are from same hypothetical_ancestor_ 419 .",
"3 and hypothetical_ancestor_419 are from same hypothetical_ancestor_ 420 .",
"hypothetical_ancestor_420 and 64 are from same hypothetical_ancestor_ 421 .",
"hypothetical_ancestor_418 and hypothetical_ancestor_421 are from same hypothetical_ancestor_ 422 .",
"hypothetical_ancestor_416 and hypothetical_ancestor_422 are from same hypothetical_ancestor_ 423 .",
"hypothetical_ancestor_415 and hypothetical_ancestor_423 are from same hypothetical_ancestor_ 424 .",
"9 and 27 are from same hypothetical_ancestor_ 425 .",
"hypothetical_ancestor_425 and 8 are from same hypothetical_ancestor_ 426 .",
"29 and 55 are from same hypothetical_ancestor_ 427 .",
"hypothetical_ancestor_426 and hypothetical_ancestor_427 are from same hypothetical_ancestor_ 428 .",
"hypothetical_ancestor_428 and 28 are from same hypothetical_ancestor_ 429 .",
"46 and 62 are from same hypothetical_ancestor_ 430 .",
"5 and 56 are from same hypothetical_ancestor_ 431 .",
"26 and 38 are from same hypothetical_ancestor_ 432 .",
"hypothetical_ancestor_431 and hypothetical_ancestor_432 are from same hypothetical_ancestor_ 433 .",
"11 and 43 are from same hypothetical_ancestor_ 434 .",
"35 and 51 are from same hypothetical_ancestor_ 435 .",
"71 and hypothetical_ancestor_435 are from same hypothetical_ancestor_ 436 .",
"hypothetical_ancestor_434 and hypothetical_ancestor_436 are from same hypothetical_ancestor_ 437 .",
"hypothetical_ancestor_433 and hypothetical_ancestor_437 are from same hypothetical_ancestor_ 438 .",
"49 and hypothetical_ancestor_438 are from same hypothetical_ancestor_ 439 .",
"hypothetical_ancestor_430 and hypothetical_ancestor_439 are from same hypothetical_ancestor_ 440 .",
"hypothetical_ancestor_429 and hypothetical_ancestor_440 are from same hypothetical_ancestor_ 441 .",
"hypothetical_ancestor_424 and hypothetical_ancestor_441 are from same hypothetical_ancestor_ 442 .",
"39 and 72 are from same hypothetical_ancestor_ 443 .",
"hypothetical_ancestor_443 and 53 are from same hypothetical_ancestor_ 444 .",
"54 and 21 are from same hypothetical_ancestor_ 445 .",
"68 and hypothetical_ancestor_445 are from same hypothetical_ancestor_ 446 .",
"hypothetical_ancestor_446 and 73 are from same hypothetical_ancestor_ 447 .",
"hypothetical_ancestor_444 and hypothetical_ancestor_447 are from same hypothetical_ancestor_ 448 .",
"13 and 42 are from same hypothetical_ancestor_ 449 .",
"hypothetical_ancestor_449 and 40 are from same hypothetical_ancestor_ 450 .",
"hypothetical_ancestor_448 and hypothetical_ancestor_450 are from same hypothetical_ancestor_ 451 .",
"34 and 59 are from same hypothetical_ancestor_ 452 .",
"hypothetical_ancestor_451 and hypothetical_ancestor_452 are from same hypothetical_ancestor_ 453 .",
"hypothetical_ancestor_442 and hypothetical_ancestor_453 are from same hypothetical_ancestor_ 454 .",
"hypothetical_ancestor_414 and hypothetical_ancestor_454 are from same hypothetical_ancestor_ 455 .",
"hypothetical_ancestor_396 and hypothetical_ancestor_455 are from same hypothetical_ancestor_ 456 .",
"hypothetical_ancestor_395 and hypothetical_ancestor_456 are from same hypothetical_ancestor_ 457 .",
"hypothetical_ancestor_394 and hypothetical_ancestor_457 are from same hypothetical_ancestor_ 458 .",
"hypothetical_ancestor_393 and hypothetical_ancestor_458 are from same hypothetical_ancestor_ 459 .",
"hypothetical_ancestor_392 and hypothetical_ancestor_459 are from same hypothetical_ancestor_ 460 .",
"hypothetical_ancestor_391 and hypothetical_ancestor_460 are from same hypothetical_ancestor_ 461 .",
"6 and hypothetical_ancestor_461 are from same hypothetical_ancestor_ 462 .",
"hypothetical_ancestor_389 and hypothetical_ancestor_462 are from same hypothetical_ancestor_ 463 .",
"hypothetical_ancestor_386 and hypothetical_ancestor_463 are from same hypothetical_ancestor_ 464 .",
"77 and hypothetical_ancestor_464 are from same hypothetical_ancestor_ 465 .",
"430 and hypothetical_ancestor_465 are from same hypothetical_ancestor_ 466 .",
"hypothetical_ancestor_355 and hypothetical_ancestor_466 are from same hypothetical_ancestor_ 467 .",
"hypothetical_ancestor_348 and hypothetical_ancestor_467 are from same hypothetical_ancestor_ 468 .",
"hypothetical_ancestor_332 and hypothetical_ancestor_468 are from same hypothetical_ancestor_ 469 .",
"hypothetical_ancestor_326 and hypothetical_ancestor_469 are from same hypothetical_ancestor_ 470 .",
"hypothetical_ancestor_325 and hypothetical_ancestor_470 are from same hypothetical_ancestor_ 471 .",
"363 and hypothetical_ancestor_471 are from same hypothetical_ancestor_ 472 .",
"hypothetical_ancestor_254 and hypothetical_ancestor_472 are from same hypothetical_ancestor_ 473 .",
"hypothetical_ancestor_5 and hypothetical_ancestor_473 are from same hypothetical_ancestor_ 474 .",
"hypothetical_ancestor_1 and hypothetical_ancestor_474 are from same hypothetical_ancestor_ 475 ."
]

questions = [
    ("Who is the common ancestor of 187 and 188", "hypothetical_ancestor_ 1"),
    ("Who is the common ancestor of 379 and 380", "hypothetical_ancestor_ 2"),
    ("Who is the common ancestor of 361 and 362", "hypothetical_ancestor_ 4"),
    ("Who is the common ancestor of 163 and hypothetical_ancestor_ 6", "hypothetical_ancestor_ 7"),
    ("Who is the common ancestor of 127 and hypothetical_ancestor_ 10", "hypothetical_ancestor_ 11"),
    ("Who is the common ancestor of 143 and 471", "hypothetical_ancestor_ 18"),
    ("Who is the common ancestor of 152 and hypothetical_ancestor_23", "hypothetical_ancestor_ 24"),
    ("Who is the common ancestor of 132 and hypothetical_ancestor_40", "hypothetical_ancestor_ 41"),
    ("Who is the common ancestor of 175 and 171", "hypothetical_ancestor_ 53"),
    ("Who is the common ancestor of 298 and hypothetical_ancestor_272", "hypothetical_ancestor_ 273"),
    ("Who is the common ancestor of hypothetical_ancestor_350 and hypothetical_ancestor_352", "hypothetical_ancestor_ 353"),
    ("Who are the children of hypothetical_ancestor_ 66", "352 and hypothetical_ancestor_65"),
    ("Who are the children of hypothetical_ancestor_ 206", "417 and 416"),
    ("Who are the children of hypothetical_ancestor_ 110", "213 and 214"),
    ("Who are the children of hypothetical_ancestor_ 167", "hypothetical_ancestor_166 and 226"),
    ("Who are the children of hypothetical_ancestor_ 417", "65 and 70"),
    ("Who are the children of hypothetical_ancestor_ 335", "112 and 117"),
    ("Who is the parent of 431", "hypothetical_ancestor_ 304"),
    ("Who is the parent of hypothetical_ancestor_466", "hypothetical_ancestor_ 467"),
    ("Who is the parent of 71", "hypothetical_ancestor_ 436")
]

# generate answers and calculate F1 score
true_labels = []
predicted_labels = []
for question in questions:
    true_labels.append(question[1])
    answer = generate_answer(question[0], ' '.join(sentences))
    print(f"Q: {question[0]}")
    print(f"A: {answer}")
    predicted_labels.append(answer.strip())


y_true = true_labels
y_pred = predicted_labels
f1 = f1_score(y_true, y_pred, average="weighted")
precision = precision_score(y_true, y_pred, average="weighted")
recall = recall_score(y_true, y_pred, average="weighted")

exact_match = 0
n = len(y_true)
for i in range(n):
  if y_true[i]==y_pred[i]:
    exact_match = exact_match + 1
#exact_match = int(y_true == y_pred)

# Print the output and metrics
print("Evaluation Metrics:")
print("F1-score:", f1)
print("Precision:", precision)
print("Recall:", recall)
print("Exact Match:", exact_match)

# %% [markdown]
# # **T5_BioQA F1_Score**

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# Load the tokenizer and model
import torch
from transformers import T5ForConditionalGeneration, T5Tokenizer
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = T5ForConditionalGeneration.from_pretrained("ozcangundes/T5-base-for-BioQA").to(device)
tokenizer = T5Tokenizer.from_pretrained("ozcangundes/T5-base-for-BioQA")

# define the function to generate answers
def generate_answer(question, context):
    input_str = "question: " + question + " context: " + context #+ " </s>"
    input_ids = tokenizer.encode(input_str, return_tensors="pt").to(device)
    outputs = model.generate(input_ids)
    # print("Output")
    # print(tokenizer.decode(outputs[0]))
    tem = tokenizer.decode(outputs[0])
    ans = ""
    n = len(tem)
    f = True
    for c in range(0,n):
      if tem[c]=='<':
        f = False
      elif tem[c]=='>':
        f = True
      else:
        if f==True:
          ans = ans + tem[c]
    print(ans)
    return ans
    # return tokenizer.decode(outputs[0])

# define the function to calculate F1 score
def calculate_f1_score(true_labels, predicted_labels):
    return f1_score(true_labels, predicted_labels, average='weighted')

# example sentences
sentences = [
"187 and 188 are from same hypothetical_ancestor_ 1 .",
"379 and 380 are from same hypothetical_ancestor_ 2 .",
"378 and hypothetical_ancestor_2 are from same hypothetical_ancestor_ 3 .",
"361 and 362 are from same hypothetical_ancestor_ 4 .",
"hypothetical_ancestor_3 and hypothetical_ancestor_4 are from same hypothetical_ancestor_ 5 .",
"159 and 162 are from same hypothetical_ancestor_ 6 .",
"163 and hypothetical_ancestor_6 are from same hypothetical_ancestor_ 7 .",
"164 and hypothetical_ancestor_7 are from same hypothetical_ancestor_ 8 .",
"161 and hypothetical_ancestor_8 are from same hypothetical_ancestor_ 9 .",
"154 and 155 are from same hypothetical_ancestor_ 10 .",
"127 and hypothetical_ancestor_10 are from same hypothetical_ancestor_ 11 .",
"177 and 179 are from same hypothetical_ancestor_ 12 .",
"178 and hypothetical_ancestor_12 are from same hypothetical_ancestor_ 13 .",
"180 and hypothetical_ancestor_13 are from same hypothetical_ancestor_ 14 .",
"186 and hypothetical_ancestor_14 are from same hypothetical_ancestor_ 15 .",
"hypothetical_ancestor_11 and hypothetical_ancestor_15 are from same hypothetical_ancestor_ 16 .",
"153 and 156 are from same hypothetical_ancestor_ 17 .",
"143 and 471 are from same hypothetical_ancestor_ 18 .",
"145 and hypothetical_ancestor_18 are from same hypothetical_ancestor_ 19 .",
"149 and hypothetical_ancestor_19 are from same hypothetical_ancestor_ 20 .",
"139 and 140 are from same hypothetical_ancestor_ 21 .",
"147 and hypothetical_ancestor_21 are from same hypothetical_ancestor_ 22 .",
"142 and 151 are from same hypothetical_ancestor_ 23 .",
"152 and hypothetical_ancestor_23 are from same hypothetical_ancestor_ 24 .",
"150 and hypothetical_ancestor_24 are from same hypothetical_ancestor_ 25 .",
"158 and hypothetical_ancestor_25 are from same hypothetical_ancestor_ 26 .",
"hypothetical_ancestor_22 and hypothetical_ancestor_26 are from same hypothetical_ancestor_ 27 .",
"146 and hypothetical_ancestor_27 are from same hypothetical_ancestor_ 28 .",
"hypothetical_ancestor_20 and hypothetical_ancestor_28 are from same hypothetical_ancestor_ 29 .",
"144 and hypothetical_ancestor_29 are from same hypothetical_ancestor_ 30 .",
"hypothetical_ancestor_17 and hypothetical_ancestor_30 are from same hypothetical_ancestor_ 31 .",
"141 and 165 are from same hypothetical_ancestor_ 32 .",
"176 and hypothetical_ancestor_32 are from same hypothetical_ancestor_ 33 .",
"168 and hypothetical_ancestor_33 are from same hypothetical_ancestor_ 34 .",
"hypothetical_ancestor_31 and hypothetical_ancestor_34 are from same hypothetical_ancestor_ 35 .",
"148 and 174 are from same hypothetical_ancestor_ 36 .",
"hypothetical_ancestor_35 and hypothetical_ancestor_36 are from same hypothetical_ancestor_ 37 .",
"131 and 130 are from same hypothetical_ancestor_ 38 .",
"135 and 133 are from same hypothetical_ancestor_ 39 .",
"hypothetical_ancestor_38 and hypothetical_ancestor_39 are from same hypothetical_ancestor_ 40 .",
"132 and hypothetical_ancestor_40 are from same hypothetical_ancestor_ 41 .",
"134 and hypothetical_ancestor_41 are from same hypothetical_ancestor_ 42 .",
"136 and hypothetical_ancestor_42 are from same hypothetical_ancestor_ 43 .",
"427 and 428 are from same hypothetical_ancestor_ 44 .",
"429 and hypothetical_ancestor_44 are from same hypothetical_ancestor_ 45 .",
"423 and 426 are from same hypothetical_ancestor_ 46 .",
"424 and hypothetical_ancestor_46 are from same hypothetical_ancestor_ 47 .",
"425 and hypothetical_ancestor_47 are from same hypothetical_ancestor_ 48 .",
"hypothetical_ancestor_45 and hypothetical_ancestor_48 are from same hypothetical_ancestor_ 49 .",
"hypothetical_ancestor_43 and hypothetical_ancestor_49 are from same hypothetical_ancestor_ 50 .",
"138 and hypothetical_ancestor_50 are from same hypothetical_ancestor_ 51 .",
"166 and 280 are from same hypothetical_ancestor_ 52 .",
"175 and 171 are from same hypothetical_ancestor_ 53 .",
"hypothetical_ancestor_52 and hypothetical_ancestor_53 are from same hypothetical_ancestor_ 54 .",
"453 and 456 are from same hypothetical_ancestor_ 55 .",
"462 and 463 are from same hypothetical_ancestor_ 56 .",
"458 and hypothetical_ancestor_56 are from same hypothetical_ancestor_ 57 .",
"457 and 461 are from same hypothetical_ancestor_ 58 .",
"459 and hypothetical_ancestor_58 are from same hypothetical_ancestor_ 59 .",
"hypothetical_ancestor_57 and hypothetical_ancestor_59 are from same hypothetical_ancestor_ 60 .",
"454 and hypothetical_ancestor_60 are from same hypothetical_ancestor_ 61 .",
"hypothetical_ancestor_55 and hypothetical_ancestor_61 are from same hypothetical_ancestor_ 62 .",
"455 and 460 are from same hypothetical_ancestor_ 63 .",
"350 and hypothetical_ancestor_63 are from same hypothetical_ancestor_ 64 .",
"349 and 351 are from same hypothetical_ancestor_ 65 .",
"352 and hypothetical_ancestor_65 are from same hypothetical_ancestor_ 66 .",
"hypothetical_ancestor_64 and hypothetical_ancestor_66 are from same hypothetical_ancestor_ 67 .",
"330 and 334 are from same hypothetical_ancestor_ 68 .",
"331 and 335 are from same hypothetical_ancestor_ 69 .",
"332 and hypothetical_ancestor_69 are from same hypothetical_ancestor_ 70 .",
"hypothetical_ancestor_68 and hypothetical_ancestor_70 are from same hypothetical_ancestor_ 71 .",
"329 and 333 are from same hypothetical_ancestor_ 72 .",
"hypothetical_ancestor_71 and hypothetical_ancestor_72 are from same hypothetical_ancestor_ 73 .",
"hypothetical_ancestor_67 and hypothetical_ancestor_73 are from same hypothetical_ancestor_ 74 .",
"326 and 328 are from same hypothetical_ancestor_ 75 .",
"327 and hypothetical_ancestor_75 are from same hypothetical_ancestor_ 76 .",
"342 and 357 are from same hypothetical_ancestor_ 77 .",
"hypothetical_ancestor_76 and hypothetical_ancestor_77 are from same hypothetical_ancestor_ 78 .",
"343 and 344 are from same hypothetical_ancestor_ 79 .",
"345 and 347 are from same hypothetical_ancestor_ 80 .",
"346 and hypothetical_ancestor_80 are from same hypothetical_ancestor_ 81 .",
"hypothetical_ancestor_79 and hypothetical_ancestor_81 are from same hypothetical_ancestor_ 82 .",
"262 and 263 are from same hypothetical_ancestor_ 83 .",
"264 and hypothetical_ancestor_83 are from same hypothetical_ancestor_ 84 .",
"340 and hypothetical_ancestor_84 are from same hypothetical_ancestor_ 85 .",
"341 and hypothetical_ancestor_85 are from same hypothetical_ancestor_ 86 .",
"338 and 336 are from same hypothetical_ancestor_ 87 .",
"339 and hypothetical_ancestor_87 are from same hypothetical_ancestor_ 88 .",
"hypothetical_ancestor_88 and 337 are from same hypothetical_ancestor_ 89 .",
"348 and hypothetical_ancestor_89 are from same hypothetical_ancestor_ 90 .",
"358 and 359 are from same hypothetical_ancestor_ 91 .",
"353 and hypothetical_ancestor_91 are from same hypothetical_ancestor_ 92 .",
"354 and 356 are from same hypothetical_ancestor_ 93 .",
"360 and hypothetical_ancestor_93 are from same hypothetical_ancestor_ 94 .",
"hypothetical_ancestor_92 and hypothetical_ancestor_94 are from same hypothetical_ancestor_ 95 .",
"355 and hypothetical_ancestor_95 are from same hypothetical_ancestor_ 96 .",
"hypothetical_ancestor_90 and hypothetical_ancestor_96 are from same hypothetical_ancestor_ 97 .",
"hypothetical_ancestor_86 and hypothetical_ancestor_97 are from same hypothetical_ancestor_ 98 .",
"hypothetical_ancestor_82 and hypothetical_ancestor_98 are from same hypothetical_ancestor_ 99 .",
"hypothetical_ancestor_78 and hypothetical_ancestor_99 are from same hypothetical_ancestor_ 100 .",
"hypothetical_ancestor_74 and hypothetical_ancestor_100 are from same hypothetical_ancestor_ 101 .",
"hypothetical_ancestor_62 and hypothetical_ancestor_101 are from same hypothetical_ancestor_ 102 .",
"hypothetical_ancestor_54 and hypothetical_ancestor_102 are from same hypothetical_ancestor_ 103 .",
"367 and 369 are from same hypothetical_ancestor_ 104 .",
"366 and hypothetical_ancestor_104 are from same hypothetical_ancestor_ 105 .",
"170 and 173 are from same hypothetical_ancestor_ 106 .",
"365 and hypothetical_ancestor_106 are from same hypothetical_ancestor_ 107 .",
"hypothetical_ancestor_105 and hypothetical_ancestor_107 are from same hypothetical_ancestor_ 108 .",
"368 and hypothetical_ancestor_108 are from same hypothetical_ancestor_ 109 .",
"213 and 214 are from same hypothetical_ancestor_ 110 .",
"411 and 412 are from same hypothetical_ancestor_ 111 .",
"409 and 410 are from same hypothetical_ancestor_ 112 .",
"hypothetical_ancestor_111 and hypothetical_ancestor_112 are from same hypothetical_ancestor_ 113 .",
"294 and hypothetical_ancestor_113 are from same hypothetical_ancestor_ 114 .",
"452 and hypothetical_ancestor_114 are from same hypothetical_ancestor_ 115 .",
"hypothetical_ancestor_110 and hypothetical_ancestor_115 are from same hypothetical_ancestor_ 116 .",
"169 and hypothetical_ancestor_116 are from same hypothetical_ancestor_ 117 .",
"172 and hypothetical_ancestor_117 are from same hypothetical_ancestor_ 118 .",
"293 and hypothetical_ancestor_118 are from same hypothetical_ancestor_ 119 .",
"hypothetical_ancestor_109 and hypothetical_ancestor_119 are from same hypothetical_ancestor_ 120 .",
"207 and 208 are from same hypothetical_ancestor_ 121 .",
"384 and hypothetical_ancestor_121 are from same hypothetical_ancestor_ 122 .",
"404 and 184 are from same hypothetical_ancestor_ 123 .",
"292 and hypothetical_ancestor_123 are from same hypothetical_ancestor_ 124 .",
"181 and hypothetical_ancestor_124 are from same hypothetical_ancestor_ 125 .",
"395 and 397 are from same hypothetical_ancestor_ 126 .",
"396 and hypothetical_ancestor_126 are from same hypothetical_ancestor_ 127 .",
"386 and hypothetical_ancestor_127 are from same hypothetical_ancestor_ 128 .",
"221 and 223 are from same hypothetical_ancestor_ 129 .",
"267 and 215 are from same hypothetical_ancestor_ 130 .",
"hypothetical_ancestor_129 and hypothetical_ancestor_130 are from same hypothetical_ancestor_ 131 .",
"222 and hypothetical_ancestor_131 are from same hypothetical_ancestor_ 132 .",
"231 and hypothetical_ancestor_132 are from same hypothetical_ancestor_ 133 .",
"233 and hypothetical_ancestor_133 are from same hypothetical_ancestor_ 134 .",
"394 and hypothetical_ancestor_134 are from same hypothetical_ancestor_ 135 .",
"392 and hypothetical_ancestor_135 are from same hypothetical_ancestor_ 136 .",
"393 and hypothetical_ancestor_136 are from same hypothetical_ancestor_ 137 .",
"hypothetical_ancestor_128 and hypothetical_ancestor_137 are from same hypothetical_ancestor_ 138 .",
"398 and hypothetical_ancestor_138 are from same hypothetical_ancestor_ 139 .",
"391 and hypothetical_ancestor_139 are from same hypothetical_ancestor_ 140 .",
"276 and 390 are from same hypothetical_ancestor_ 141 .",
"382 and hypothetical_ancestor_141 are from same hypothetical_ancestor_ 142 .",
"381 and 383 are from same hypothetical_ancestor_ 143 .",
"415 and 413 are from same hypothetical_ancestor_ 144 .",
"414 and hypothetical_ancestor_144 are from same hypothetical_ancestor_ 145 .",
"418 and hypothetical_ancestor_145 are from same hypothetical_ancestor_ 146 .",
"385 and 399 are from same hypothetical_ancestor_ 147 .",
"400 and 402 are from same hypothetical_ancestor_ 148 .",
"401 and hypothetical_ancestor_148 are from same hypothetical_ancestor_ 149 .",
"403 and hypothetical_ancestor_149 are from same hypothetical_ancestor_ 150 .",
"389 and 388 are from same hypothetical_ancestor_ 151 .",
"hypothetical_ancestor_150 and hypothetical_ancestor_151 are from same hypothetical_ancestor_ 152 .",
"387 and hypothetical_ancestor_152 are from same hypothetical_ancestor_ 153 .",
"hypothetical_ancestor_147 and hypothetical_ancestor_153 are from same hypothetical_ancestor_ 154 .",
"hypothetical_ancestor_146 and hypothetical_ancestor_154 are from same hypothetical_ancestor_ 155 .",
"hypothetical_ancestor_143 and hypothetical_ancestor_155 are from same hypothetical_ancestor_ 156 .",
"279 and hypothetical_ancestor_156 are from same hypothetical_ancestor_ 157 .",
"hypothetical_ancestor_142 and hypothetical_ancestor_157 are from same hypothetical_ancestor_ 158 .",
"hypothetical_ancestor_140 and hypothetical_ancestor_158 are from same hypothetical_ancestor_ 159 .",
"268 and 273 are from same hypothetical_ancestor_ 160 .",
"274 and hypothetical_ancestor_160 are from same hypothetical_ancestor_ 161 .",
"216 and 219 are from same hypothetical_ancestor_ 162 .",
"hypothetical_ancestor_162 and 217 are from same hypothetical_ancestor_ 163 .",
"218 and hypothetical_ancestor_163 are from same hypothetical_ancestor_ 164 .",
"hypothetical_ancestor_161 and hypothetical_ancestor_164 are from same hypothetical_ancestor_ 165 .",
"224 and 228 are from same hypothetical_ancestor_ 166 .",
"hypothetical_ancestor_166 and 226 are from same hypothetical_ancestor_ 167 .",
"hypothetical_ancestor_167 and 225 are from same hypothetical_ancestor_ 168 .",
"227 and hypothetical_ancestor_168 are from same hypothetical_ancestor_ 169 .",
"277 and hypothetical_ancestor_169 are from same hypothetical_ancestor_ 170 .",
"370 and 371 are from same hypothetical_ancestor_ 171 .",
"372 and 373 are from same hypothetical_ancestor_ 172 .",
"hypothetical_ancestor_171 and hypothetical_ancestor_172 are from same hypothetical_ancestor_ 173 .",
"374 and hypothetical_ancestor_173 are from same hypothetical_ancestor_ 174 .",
"283 and 288 are from same hypothetical_ancestor_ 175 .",
"286 and hypothetical_ancestor_175 are from same hypothetical_ancestor_ 176 .",
"284 and hypothetical_ancestor_176 are from same hypothetical_ancestor_ 177 .",
"253 and hypothetical_ancestor_177 are from same hypothetical_ancestor_ 178 .",
"287 and hypothetical_ancestor_178 are from same hypothetical_ancestor_ 179 .",
"290 and hypothetical_ancestor_179 are from same hypothetical_ancestor_ 180 .",
"285 and hypothetical_ancestor_180 are from same hypothetical_ancestor_ 181 .",
"289 and hypothetical_ancestor_181 are from same hypothetical_ancestor_ 182 .",
"266 and hypothetical_ancestor_182 are from same hypothetical_ancestor_ 183 .",
"255 and 256 are from same hypothetical_ancestor_ 184 .",
"252 and hypothetical_ancestor_184 are from same hypothetical_ancestor_ 185 .",
"248 and 249 are from same hypothetical_ancestor_ 186 .",
"271 and hypothetical_ancestor_186 are from same hypothetical_ancestor_ 187 .",
"241 and hypothetical_ancestor_187 are from same hypothetical_ancestor_ 188 .",
"247 and hypothetical_ancestor_188 are from same hypothetical_ancestor_ 189 .",
"245 and hypothetical_ancestor_189 are from same hypothetical_ancestor_ 190 .",
"278 and hypothetical_ancestor_190 are from same hypothetical_ancestor_ 191 .",
"246 and hypothetical_ancestor_191 are from same hypothetical_ancestor_ 192 .",
"275 and hypothetical_ancestor_192 are from same hypothetical_ancestor_ 193 .",
"250 and hypothetical_ancestor_193 are from same hypothetical_ancestor_ 194 .",
"254 and hypothetical_ancestor_194 are from same hypothetical_ancestor_ 195 .",
"hypothetical_ancestor_185 and hypothetical_ancestor_195 are from same hypothetical_ancestor_ 196 .",
"hypothetical_ancestor_183 and hypothetical_ancestor_196 are from same hypothetical_ancestor_ 197 .",
"hypothetical_ancestor_174 and hypothetical_ancestor_197 are from same hypothetical_ancestor_ 198 .",
"291 and hypothetical_ancestor_198 are from same hypothetical_ancestor_ 199 .",
"203 and hypothetical_ancestor_199 are from same hypothetical_ancestor_ 200 .",
"281 and 282 are from same hypothetical_ancestor_ 201 .",
"212 and 211 are from same hypothetical_ancestor_ 202 .",
"210 and hypothetical_ancestor_202 are from same hypothetical_ancestor_ 203 .",
"hypothetical_ancestor_201 and hypothetical_ancestor_203 are from same hypothetical_ancestor_ 204 .",
"420 and 421 are from same hypothetical_ancestor_ 205 .",
"417 and 416 are from same hypothetical_ancestor_ 206 .",
"422 and hypothetical_ancestor_206 are from same hypothetical_ancestor_ 207 .",
"419 and hypothetical_ancestor_207 are from same hypothetical_ancestor_ 208 .",
"hypothetical_ancestor_205 and hypothetical_ancestor_208 are from same hypothetical_ancestor_ 209 .",
"hypothetical_ancestor_204 and hypothetical_ancestor_209 are from same hypothetical_ancestor_ 210 .",
"251 and 272 are from same hypothetical_ancestor_ 211 .",
"243 and 261 are from same hypothetical_ancestor_ 212 .",
"265 and 377 are from same hypothetical_ancestor_ 213 .",
"258 and 260 are from same hypothetical_ancestor_ 214 .",
"257 and hypothetical_ancestor_214 are from same hypothetical_ancestor_ 215 .",
"376 and 375 are from same hypothetical_ancestor_ 216 .",
"hypothetical_ancestor_215 and hypothetical_ancestor_216 are from same hypothetical_ancestor_ 217 .",
"hypothetical_ancestor_213 and hypothetical_ancestor_217 are from same hypothetical_ancestor_ 218 .",
"hypothetical_ancestor_212 and hypothetical_ancestor_218 are from same hypothetical_ancestor_ 219 .",
"hypothetical_ancestor_211 and hypothetical_ancestor_219 are from same hypothetical_ancestor_ 220 .",
"209 and 230 are from same hypothetical_ancestor_ 221 .",
"269 and 232 are from same hypothetical_ancestor_ 222 .",
"hypothetical_ancestor_221 and hypothetical_ancestor_222 are from same hypothetical_ancestor_ 223 .",
"229 and 238 are from same hypothetical_ancestor_ 224 .",
"234 and 242 are from same hypothetical_ancestor_ 225 .",
"236 and hypothetical_ancestor_225 are from same hypothetical_ancestor_ 226 .",
"hypothetical_ancestor_224 and hypothetical_ancestor_226 are from same hypothetical_ancestor_ 227 .",
"hypothetical_ancestor_223 and hypothetical_ancestor_227 are from same hypothetical_ancestor_ 228 .",
"237 and hypothetical_ancestor_228 are from same hypothetical_ancestor_ 229 .",
"239 and hypothetical_ancestor_229 are from same hypothetical_ancestor_ 230 .",
"244 and hypothetical_ancestor_230 are from same hypothetical_ancestor_ 231 .",
"235 and hypothetical_ancestor_231 are from same hypothetical_ancestor_ 232 .",
"259 and 472 are from same hypothetical_ancestor_ 233 .",
"hypothetical_ancestor_232 and hypothetical_ancestor_233 are from same hypothetical_ancestor_ 234 .",
"hypothetical_ancestor_234 and 240 are from same hypothetical_ancestor_ 235 .",
"hypothetical_ancestor_220 and hypothetical_ancestor_235 are from same hypothetical_ancestor_ 236 .",
"hypothetical_ancestor_210 and hypothetical_ancestor_236 are from same hypothetical_ancestor_ 237 .",
"hypothetical_ancestor_200 and hypothetical_ancestor_237 are from same hypothetical_ancestor_ 238 .",
"hypothetical_ancestor_170 and hypothetical_ancestor_238 are from same hypothetical_ancestor_ 239 .",
"hypothetical_ancestor_165 and hypothetical_ancestor_239 are from same hypothetical_ancestor_ 240 .",
"hypothetical_ancestor_159 and hypothetical_ancestor_240 are from same hypothetical_ancestor_ 241 .",
"270 and hypothetical_ancestor_241 are from same hypothetical_ancestor_ 242 .",
"220 and hypothetical_ancestor_242 are from same hypothetical_ancestor_ 243 .",
"hypothetical_ancestor_125 and hypothetical_ancestor_243 are from same hypothetical_ancestor_ 244 .",
"hypothetical_ancestor_122 and hypothetical_ancestor_244 are from same hypothetical_ancestor_ 245 .",
"hypothetical_ancestor_120 and hypothetical_ancestor_245 are from same hypothetical_ancestor_ 246 .",
"hypothetical_ancestor_103 and hypothetical_ancestor_246 are from same hypothetical_ancestor_ 247 .",
"hypothetical_ancestor_51 and hypothetical_ancestor_247 are from same hypothetical_ancestor_ 248 .",
"408 and hypothetical_ancestor_248 are from same hypothetical_ancestor_ 249 .",
"hypothetical_ancestor_37 and hypothetical_ancestor_249 are from same hypothetical_ancestor_ 250 .",
"hypothetical_ancestor_16 and hypothetical_ancestor_250 are from same hypothetical_ancestor_ 251 .",
"129 and hypothetical_ancestor_251 are from same hypothetical_ancestor_ 252 .",
"hypothetical_ancestor_9 and hypothetical_ancestor_252 are from same hypothetical_ancestor_ 253 .",
"128 and hypothetical_ancestor_253 are from same hypothetical_ancestor_ 254 .",
"321 and 324 are from same hypothetical_ancestor_ 255 .",
"325 and hypothetical_ancestor_255 are from same hypothetical_ancestor_ 256 .",
"322 and hypothetical_ancestor_256 are from same hypothetical_ancestor_ 257 .",
"323 and hypothetical_ancestor_257 are from same hypothetical_ancestor_ 258 .",
"476 and 473 are from same hypothetical_ancestor_ 259 .",
"160 and hypothetical_ancestor_259 are from same hypothetical_ancestor_ 260 .",
"475 and 474 are from same hypothetical_ancestor_ 261 .",
"185 and hypothetical_ancestor_261 are from same hypothetical_ancestor_ 262 .",
"hypothetical_ancestor_260 and hypothetical_ancestor_262 are from same hypothetical_ancestor_ 263 .",
"hypothetical_ancestor_258 and hypothetical_ancestor_263 are from same hypothetical_ancestor_ 264 .",
"310 and 313 are from same hypothetical_ancestor_ 265 .",
"315 and 320 are from same hypothetical_ancestor_ 266 .",
"316 and 317 are from same hypothetical_ancestor_ 267 .",
"hypothetical_ancestor_266 and hypothetical_ancestor_267 are from same hypothetical_ancestor_ 268 .",
"314 and hypothetical_ancestor_268 are from same hypothetical_ancestor_ 269 .",
"309 and hypothetical_ancestor_269 are from same hypothetical_ancestor_ 270 .",
"hypothetical_ancestor_265 and hypothetical_ancestor_270 are from same hypothetical_ancestor_ 271 .",
"301 and 306 are from same hypothetical_ancestor_ 272 .",
"298 and hypothetical_ancestor_272 are from same hypothetical_ancestor_ 273 .",
"300 and hypothetical_ancestor_273 are from same hypothetical_ancestor_ 274 .",
"311 and hypothetical_ancestor_274 are from same hypothetical_ancestor_ 275 .",
"303 and hypothetical_ancestor_275 are from same hypothetical_ancestor_ 276 .",
"295 and hypothetical_ancestor_276 are from same hypothetical_ancestor_ 277 .",
"296 and hypothetical_ancestor_277 are from same hypothetical_ancestor_ 278 .",
"305 and 318 are from same hypothetical_ancestor_ 279 .",
"297 and hypothetical_ancestor_279 are from same hypothetical_ancestor_ 280 .",
"304 and hypothetical_ancestor_280 are from same hypothetical_ancestor_ 281 .",
"302 and 307 are from same hypothetical_ancestor_ 282 .",
"299 and hypothetical_ancestor_282 are from same hypothetical_ancestor_ 283 .",
"312 and hypothetical_ancestor_283 are from same hypothetical_ancestor_ 284 .",
"hypothetical_ancestor_281 and hypothetical_ancestor_284 are from same hypothetical_ancestor_ 285 .",
"308 and hypothetical_ancestor_285 are from same hypothetical_ancestor_ 286 .",
"319 and hypothetical_ancestor_286 are from same hypothetical_ancestor_ 287 .",
"hypothetical_ancestor_278 and hypothetical_ancestor_287 are from same hypothetical_ancestor_ 288 .",
"hypothetical_ancestor_271 and hypothetical_ancestor_288 are from same hypothetical_ancestor_ 289 .",
"hypothetical_ancestor_264 and hypothetical_ancestor_289 are from same hypothetical_ancestor_ 290 .",
"191 and 198 are from same hypothetical_ancestor_ 291 .",
"190 and 194 are from same hypothetical_ancestor_ 292 .",
"189 and 192 are from same hypothetical_ancestor_ 293 .",
"hypothetical_ancestor_292 and hypothetical_ancestor_293 are from same hypothetical_ancestor_ 294 .",
"196 and 197 are from same hypothetical_ancestor_ 295 .",
"195 and 201 are from same hypothetical_ancestor_ 296 .",
"202 and hypothetical_ancestor_296 are from same hypothetical_ancestor_ 297 .",
"hypothetical_ancestor_295 and hypothetical_ancestor_297 are from same hypothetical_ancestor_ 298 .",
"200 and hypothetical_ancestor_298 are from same hypothetical_ancestor_ 299 .",
"hypothetical_ancestor_294 and hypothetical_ancestor_299 are from same hypothetical_ancestor_ 300 .",
"193 and hypothetical_ancestor_300 are from same hypothetical_ancestor_ 301 .",
"hypothetical_ancestor_291 and hypothetical_ancestor_301 are from same hypothetical_ancestor_ 302 .",
"199 and hypothetical_ancestor_302 are from same hypothetical_ancestor_ 303 .",
"431 and 432 are from same hypothetical_ancestor_ 304 .",
"436 and 447 are from same hypothetical_ancestor_ 305 .",
"439 and 442 are from same hypothetical_ancestor_ 306 .",
"435 and hypothetical_ancestor_306 are from same hypothetical_ancestor_ 307 .",
"448 and hypothetical_ancestor_307 are from same hypothetical_ancestor_ 308 .",
"hypothetical_ancestor_305 and hypothetical_ancestor_308 are from same hypothetical_ancestor_ 309 .",
"433 and 441 are from same hypothetical_ancestor_ 310 .",
"437 and 440 are from same hypothetical_ancestor_ 311 .",
"443 and 449 are from same hypothetical_ancestor_ 312 .",
"450 and hypothetical_ancestor_312 are from same hypothetical_ancestor_ 313 .",
"445 and 446 are from same hypothetical_ancestor_ 314 .",
"451 and hypothetical_ancestor_314 are from same hypothetical_ancestor_ 315 .",
"438 and hypothetical_ancestor_315 are from same hypothetical_ancestor_ 316 .",
"hypothetical_ancestor_313 and hypothetical_ancestor_316 are from same hypothetical_ancestor_ 317 .",
"444 and hypothetical_ancestor_317 are from same hypothetical_ancestor_ 318 .",
"hypothetical_ancestor_311 and hypothetical_ancestor_318 are from same hypothetical_ancestor_ 319 .",
"hypothetical_ancestor_310 and hypothetical_ancestor_319 are from same hypothetical_ancestor_ 320 .",
"434 and hypothetical_ancestor_320 are from same hypothetical_ancestor_ 321 .",
"hypothetical_ancestor_309 and hypothetical_ancestor_321 are from same hypothetical_ancestor_ 322 .",
"hypothetical_ancestor_304 and hypothetical_ancestor_322 are from same hypothetical_ancestor_ 323 .",
"hypothetical_ancestor_303 and hypothetical_ancestor_323 are from same hypothetical_ancestor_ 324 .",
"hypothetical_ancestor_290 and hypothetical_ancestor_324 are from same hypothetical_ancestor_ 325 .",
"137 and 167 are from same hypothetical_ancestor_ 326 .",
"464 and 465 are from same hypothetical_ancestor_ 327 .",
"466 and 470 are from same hypothetical_ancestor_ 328 .",
"467 and hypothetical_ancestor_328 are from same hypothetical_ancestor_ 329 .",
"469 and hypothetical_ancestor_329 are from same hypothetical_ancestor_ 330 .",
"468 and hypothetical_ancestor_330 are from same hypothetical_ancestor_ 331 .",
"hypothetical_ancestor_327 and hypothetical_ancestor_331 are from same hypothetical_ancestor_ 332 .",
"182 and 183 are from same hypothetical_ancestor_ 333 .",
"120 and hypothetical_ancestor_333 are from same hypothetical_ancestor_ 334 .",
"112 and 117 are from same hypothetical_ancestor_ 335 .",
"113 and 116 are from same hypothetical_ancestor_ 336 .",
"114 and 118 are from same hypothetical_ancestor_ 337 .",
"hypothetical_ancestor_336 and hypothetical_ancestor_337 are from same hypothetical_ancestor_ 338 .",
"hypothetical_ancestor_335 and hypothetical_ancestor_338 are from same hypothetical_ancestor_ 339 .",
"115 and hypothetical_ancestor_339 are from same hypothetical_ancestor_ 340 .",
"123 and 125 are from same hypothetical_ancestor_ 341 .",
"124 and hypothetical_ancestor_341 are from same hypothetical_ancestor_ 342 .",
"126 and hypothetical_ancestor_342 are from same hypothetical_ancestor_ 343 .",
"119 and hypothetical_ancestor_343 are from same hypothetical_ancestor_ 344 .",
"121 and hypothetical_ancestor_344 are from same hypothetical_ancestor_ 345 .",
"hypothetical_ancestor_340 and hypothetical_ancestor_345 are from same hypothetical_ancestor_ 346 .",
"157 and hypothetical_ancestor_346 are from same hypothetical_ancestor_ 347 .",
"hypothetical_ancestor_334 and hypothetical_ancestor_347 are from same hypothetical_ancestor_ 348 .",
"204 and 205 are from same hypothetical_ancestor_ 349 .",
"364 and 206 are from same hypothetical_ancestor_ 350 .",
"407 and 405 are from same hypothetical_ancestor_ 351 .",
"406 and hypothetical_ancestor_351 are from same hypothetical_ancestor_ 352 .",
"hypothetical_ancestor_350 and hypothetical_ancestor_352 are from same hypothetical_ancestor_ 353 .",
"hypothetical_ancestor_349 and hypothetical_ancestor_353 are from same hypothetical_ancestor_ 354 .",
"122 and hypothetical_ancestor_354 are from same hypothetical_ancestor_ 355 .",
"105 and 100 are from same hypothetical_ancestor_ 356 .",
"102 and hypothetical_ancestor_356 are from same hypothetical_ancestor_ 357 .",
"92 and hypothetical_ancestor_357 are from same hypothetical_ancestor_ 358 .",
"88 and 101 are from same hypothetical_ancestor_ 359 .",
"75 and 85 are from same hypothetical_ancestor_ 360 .",
"82 and 106 are from same hypothetical_ancestor_ 361 .",
"hypothetical_ancestor_360 and hypothetical_ancestor_361 are from same hypothetical_ancestor_ 362 .",
"96 and hypothetical_ancestor_362 are from same hypothetical_ancestor_ 363 .",
"83 and 94 are from same hypothetical_ancestor_ 364 .",
"97 and 99 are from same hypothetical_ancestor_ 365 .",
"103 and 110 are from same hypothetical_ancestor_ 366 .",
"hypothetical_ancestor_365 and hypothetical_ancestor_366 are from same hypothetical_ancestor_ 367 .",
"104 and hypothetical_ancestor_367 are from same hypothetical_ancestor_ 368 .",
"91 and hypothetical_ancestor_368 are from same hypothetical_ancestor_ 369 .",
"hypothetical_ancestor_364 and hypothetical_ancestor_369 are from same hypothetical_ancestor_ 370 .",
"hypothetical_ancestor_363 and hypothetical_ancestor_370 are from same hypothetical_ancestor_ 371 .",
"109 and 84 are from same hypothetical_ancestor_ 372 .",
"98 and hypothetical_ancestor_372 are from same hypothetical_ancestor_ 373 .",
"89 and hypothetical_ancestor_373 are from same hypothetical_ancestor_ 374 .",
"86 and 111 are from same hypothetical_ancestor_ 375 .",
"90 and hypothetical_ancestor_375 are from same hypothetical_ancestor_ 376 .",
"95 and 107 are from same hypothetical_ancestor_ 377 .",
"108 and hypothetical_ancestor_377 are from same hypothetical_ancestor_ 378 .",
"93 and hypothetical_ancestor_378 are from same hypothetical_ancestor_ 379 .",
"hypothetical_ancestor_379 and 76 are from same hypothetical_ancestor_ 380 .",
"hypothetical_ancestor_376 and hypothetical_ancestor_380 are from same hypothetical_ancestor_ 381 .",
"hypothetical_ancestor_374 and hypothetical_ancestor_381 are from same hypothetical_ancestor_ 382 .",
"87 and hypothetical_ancestor_382 are from same hypothetical_ancestor_ 383 .",
"hypothetical_ancestor_371 and hypothetical_ancestor_383 are from same hypothetical_ancestor_ 384 .",
"hypothetical_ancestor_359 and hypothetical_ancestor_384 are from same hypothetical_ancestor_ 385 .",
"hypothetical_ancestor_358 and hypothetical_ancestor_385 are from same hypothetical_ancestor_ 386 .",
"80 and 79 are from same hypothetical_ancestor_ 387 .",
"78 and hypothetical_ancestor_387 are from same hypothetical_ancestor_ 388 .",
"81 and hypothetical_ancestor_388 are from same hypothetical_ancestor_ 389 .",
"69 and 33 are from same hypothetical_ancestor_ 390 .",
"hypothetical_ancestor_390 and 19 are from same hypothetical_ancestor_ 391 .",
"20 and 67 are from same hypothetical_ancestor_ 392 .",
"1 and 22 are from same hypothetical_ancestor_ 393 .",
"12 and 52 are from same hypothetical_ancestor_ 394 .",
"37 and 50 are from same hypothetical_ancestor_ 395 .",
"2 and 58 are from same hypothetical_ancestor_ 396 .",
"36 and 16 are from same hypothetical_ancestor_ 397 .",
"23 and 61 are from same hypothetical_ancestor_ 398 .",
"hypothetical_ancestor_397 and hypothetical_ancestor_398 are from same hypothetical_ancestor_ 399 .",
"25 and 30 are from same hypothetical_ancestor_ 400 .",
"hypothetical_ancestor_400 and 24 are from same hypothetical_ancestor_ 401 .",
"60 and hypothetical_ancestor_401 are from same hypothetical_ancestor_ 402 .",
"57 and 48 are from same hypothetical_ancestor_ 403 .",
"hypothetical_ancestor_403 and 17 are from same hypothetical_ancestor_ 404 .",
"hypothetical_ancestor_404 and 47 are from same hypothetical_ancestor_ 405 .",
"hypothetical_ancestor_402 and hypothetical_ancestor_405 are from same hypothetical_ancestor_ 406 .",
"32 and 44 are from same hypothetical_ancestor_ 407 .",
"14 and hypothetical_ancestor_407 are from same hypothetical_ancestor_ 408 .",
"4 and 31 are from same hypothetical_ancestor_ 409 .",
"hypothetical_ancestor_408 and hypothetical_ancestor_409 are from same hypothetical_ancestor_ 410 .",
"45 and 66 are from same hypothetical_ancestor_ 411 .",
"hypothetical_ancestor_410 and hypothetical_ancestor_411 are from same hypothetical_ancestor_ 412 .",
"hypothetical_ancestor_406 and hypothetical_ancestor_412 are from same hypothetical_ancestor_ 413 .",
"hypothetical_ancestor_399 and hypothetical_ancestor_413 are from same hypothetical_ancestor_ 414 .",
"18 and 63 are from same hypothetical_ancestor_ 415 .",
"7 and 41 are from same hypothetical_ancestor_ 416 .",
"65 and 70 are from same hypothetical_ancestor_ 417 .",
"10 and hypothetical_ancestor_417 are from same hypothetical_ancestor_ 418 .",
"15 and 74 are from same hypothetical_ancestor_ 419 .",
"3 and hypothetical_ancestor_419 are from same hypothetical_ancestor_ 420 .",
"hypothetical_ancestor_420 and 64 are from same hypothetical_ancestor_ 421 .",
"hypothetical_ancestor_418 and hypothetical_ancestor_421 are from same hypothetical_ancestor_ 422 .",
"hypothetical_ancestor_416 and hypothetical_ancestor_422 are from same hypothetical_ancestor_ 423 .",
"hypothetical_ancestor_415 and hypothetical_ancestor_423 are from same hypothetical_ancestor_ 424 .",
"9 and 27 are from same hypothetical_ancestor_ 425 .",
"hypothetical_ancestor_425 and 8 are from same hypothetical_ancestor_ 426 .",
"29 and 55 are from same hypothetical_ancestor_ 427 .",
"hypothetical_ancestor_426 and hypothetical_ancestor_427 are from same hypothetical_ancestor_ 428 .",
"hypothetical_ancestor_428 and 28 are from same hypothetical_ancestor_ 429 .",
"46 and 62 are from same hypothetical_ancestor_ 430 .",
"5 and 56 are from same hypothetical_ancestor_ 431 .",
"26 and 38 are from same hypothetical_ancestor_ 432 .",
"hypothetical_ancestor_431 and hypothetical_ancestor_432 are from same hypothetical_ancestor_ 433 .",
"11 and 43 are from same hypothetical_ancestor_ 434 .",
"35 and 51 are from same hypothetical_ancestor_ 435 .",
"71 and hypothetical_ancestor_435 are from same hypothetical_ancestor_ 436 .",
"hypothetical_ancestor_434 and hypothetical_ancestor_436 are from same hypothetical_ancestor_ 437 .",
"hypothetical_ancestor_433 and hypothetical_ancestor_437 are from same hypothetical_ancestor_ 438 .",
"49 and hypothetical_ancestor_438 are from same hypothetical_ancestor_ 439 .",
"hypothetical_ancestor_430 and hypothetical_ancestor_439 are from same hypothetical_ancestor_ 440 .",
"hypothetical_ancestor_429 and hypothetical_ancestor_440 are from same hypothetical_ancestor_ 441 .",
"hypothetical_ancestor_424 and hypothetical_ancestor_441 are from same hypothetical_ancestor_ 442 .",
"39 and 72 are from same hypothetical_ancestor_ 443 .",
"hypothetical_ancestor_443 and 53 are from same hypothetical_ancestor_ 444 .",
"54 and 21 are from same hypothetical_ancestor_ 445 .",
"68 and hypothetical_ancestor_445 are from same hypothetical_ancestor_ 446 .",
"hypothetical_ancestor_446 and 73 are from same hypothetical_ancestor_ 447 .",
"hypothetical_ancestor_444 and hypothetical_ancestor_447 are from same hypothetical_ancestor_ 448 .",
"13 and 42 are from same hypothetical_ancestor_ 449 .",
"hypothetical_ancestor_449 and 40 are from same hypothetical_ancestor_ 450 .",
"hypothetical_ancestor_448 and hypothetical_ancestor_450 are from same hypothetical_ancestor_ 451 .",
"34 and 59 are from same hypothetical_ancestor_ 452 .",
"hypothetical_ancestor_451 and hypothetical_ancestor_452 are from same hypothetical_ancestor_ 453 .",
"hypothetical_ancestor_442 and hypothetical_ancestor_453 are from same hypothetical_ancestor_ 454 .",
"hypothetical_ancestor_414 and hypothetical_ancestor_454 are from same hypothetical_ancestor_ 455 .",
"hypothetical_ancestor_396 and hypothetical_ancestor_455 are from same hypothetical_ancestor_ 456 .",
"hypothetical_ancestor_395 and hypothetical_ancestor_456 are from same hypothetical_ancestor_ 457 .",
"hypothetical_ancestor_394 and hypothetical_ancestor_457 are from same hypothetical_ancestor_ 458 .",
"hypothetical_ancestor_393 and hypothetical_ancestor_458 are from same hypothetical_ancestor_ 459 .",
"hypothetical_ancestor_392 and hypothetical_ancestor_459 are from same hypothetical_ancestor_ 460 .",
"hypothetical_ancestor_391 and hypothetical_ancestor_460 are from same hypothetical_ancestor_ 461 .",
"6 and hypothetical_ancestor_461 are from same hypothetical_ancestor_ 462 .",
"hypothetical_ancestor_389 and hypothetical_ancestor_462 are from same hypothetical_ancestor_ 463 .",
"hypothetical_ancestor_386 and hypothetical_ancestor_463 are from same hypothetical_ancestor_ 464 .",
"77 and hypothetical_ancestor_464 are from same hypothetical_ancestor_ 465 .",
"430 and hypothetical_ancestor_465 are from same hypothetical_ancestor_ 466 .",
"hypothetical_ancestor_355 and hypothetical_ancestor_466 are from same hypothetical_ancestor_ 467 .",
"hypothetical_ancestor_348 and hypothetical_ancestor_467 are from same hypothetical_ancestor_ 468 .",
"hypothetical_ancestor_332 and hypothetical_ancestor_468 are from same hypothetical_ancestor_ 469 .",
"hypothetical_ancestor_326 and hypothetical_ancestor_469 are from same hypothetical_ancestor_ 470 .",
"hypothetical_ancestor_325 and hypothetical_ancestor_470 are from same hypothetical_ancestor_ 471 .",
"363 and hypothetical_ancestor_471 are from same hypothetical_ancestor_ 472 .",
"hypothetical_ancestor_254 and hypothetical_ancestor_472 are from same hypothetical_ancestor_ 473 .",
"hypothetical_ancestor_5 and hypothetical_ancestor_473 are from same hypothetical_ancestor_ 474 .",
"hypothetical_ancestor_1 and hypothetical_ancestor_474 are from same hypothetical_ancestor_ 475 ."
]

questions = [
    ("Who is the common ancestor of 187 and 188", "hypothetical_ancestor_ 1"),
    ("Who is the common ancestor of 379 and 380", "hypothetical_ancestor_ 2"),
    ("Who is the common ancestor of 361 and 362", "hypothetical_ancestor_ 4"),
    ("Who is the common ancestor of 163 and hypothetical_ancestor_ 6", "hypothetical_ancestor_ 7"),
    ("Who is the common ancestor of 127 and hypothetical_ancestor_ 10", "hypothetical_ancestor_ 11"),
    ("Who is the common ancestor of 143 and 471", "hypothetical_ancestor_ 18"),
    ("Who is the common ancestor of 152 and hypothetical_ancestor_23", "hypothetical_ancestor_ 24"),
    ("Who is the common ancestor of 132 and hypothetical_ancestor_40", "hypothetical_ancestor_ 41"),
    ("Who is the common ancestor of 175 and 171", "hypothetical_ancestor_ 53"),
    ("Who is the common ancestor of 298 and hypothetical_ancestor_272", "hypothetical_ancestor_ 273"),
    ("Who is the common ancestor of hypothetical_ancestor_350 and hypothetical_ancestor_352", "hypothetical_ancestor_ 353"),
    ("Who are the children of hypothetical_ancestor_ 66", "352 and hypothetical_ancestor_65"),
    ("Who are the children of hypothetical_ancestor_ 206", "417 and 416"),
    ("Who are the children of hypothetical_ancestor_ 110", "213 and 214"),
    ("Who are the children of hypothetical_ancestor_ 167", "hypothetical_ancestor_166 and 226"),
    ("Who are the children of hypothetical_ancestor_ 417", "65 and 70"),
    ("Who are the children of hypothetical_ancestor_ 335", "112 and 117"),
    ("Who is the parent of 431", "hypothetical_ancestor_ 304"),
    ("Who is the parent of hypothetical_ancestor_466", "hypothetical_ancestor_ 467"),
    ("Who is the parent of 71", "hypothetical_ancestor_ 436")
]

# generate answers and calculate F1 score
true_labels = []
predicted_labels = []
for question in questions:
    true_labels.append(question[1])
    answer = generate_answer(question[0], ' '.join(sentences))
    print(f"Q: {question[0]}")
    print(f"A: {answer}")
    predicted_labels.append(answer.strip())


y_true = true_labels
y_pred = predicted_labels
f1 = f1_score(y_true, y_pred, average="weighted")
precision = precision_score(y_true, y_pred, average="weighted")
recall = recall_score(y_true, y_pred, average="weighted")
#exact_match = int(y_true == y_pred)
exact_match = 0
n = len(y_true)
for i in range(n):
  if y_true[i]==y_pred[i]:
    exact_match = exact_match + 1

# Print the output and metrics
print("Evaluation Metrics:")
print("F1-score:", f1)
print("Precision:", precision)
print("Recall:", recall)
print("Exact Match:", exact_match)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (10055 > 512). Running this sequence through the model will result in indexing errors

# %% [markdown]
# # **ALBERT F1_Score**

# %%
import torch
from transformers import pipeline, AutoTokenizer, AutoModelForQuestionAnswering

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load ALBERT model and tokenizer
model_name = "mfeb/albert-xxlarge-v2-squad2"
model = AutoModelForQuestionAnswering.from_pretrained(model_name).to(device)
tokenizer = AutoTokenizer.from_pretrained(model_name)

# define the function to generate answers
def generate_answer(question, context):
    nlp = pipeline('question-answering', model=model, tokenizer=tokenizer, device=device)
    result = nlp(question=question, context=context)
    answer = result['answer']
    return answer

# define the function to calculate F1 score
def calculate_f1_score(true_labels, predicted_labels):
    return f1_score(true_labels, predicted_labels, average='weighted')

# example sentences
sentences = [
"187 and 188 are from same hypothetical_ancestor_ 1 .",
"379 and 380 are from same hypothetical_ancestor_ 2 .",
"378 and hypothetical_ancestor_2 are from same hypothetical_ancestor_ 3 .",
"361 and 362 are from same hypothetical_ancestor_ 4 .",
"hypothetical_ancestor_3 and hypothetical_ancestor_4 are from same hypothetical_ancestor_ 5 .",
"159 and 162 are from same hypothetical_ancestor_ 6 .",
"163 and hypothetical_ancestor_6 are from same hypothetical_ancestor_ 7 .",
"164 and hypothetical_ancestor_7 are from same hypothetical_ancestor_ 8 .",
"161 and hypothetical_ancestor_8 are from same hypothetical_ancestor_ 9 .",
"154 and 155 are from same hypothetical_ancestor_ 10 .",
"127 and hypothetical_ancestor_10 are from same hypothetical_ancestor_ 11 .",
"177 and 179 are from same hypothetical_ancestor_ 12 .",
"178 and hypothetical_ancestor_12 are from same hypothetical_ancestor_ 13 .",
"180 and hypothetical_ancestor_13 are from same hypothetical_ancestor_ 14 .",
"186 and hypothetical_ancestor_14 are from same hypothetical_ancestor_ 15 .",
"hypothetical_ancestor_11 and hypothetical_ancestor_15 are from same hypothetical_ancestor_ 16 .",
"153 and 156 are from same hypothetical_ancestor_ 17 .",
"143 and 471 are from same hypothetical_ancestor_ 18 .",
"145 and hypothetical_ancestor_18 are from same hypothetical_ancestor_ 19 .",
"149 and hypothetical_ancestor_19 are from same hypothetical_ancestor_ 20 .",
"139 and 140 are from same hypothetical_ancestor_ 21 .",
"147 and hypothetical_ancestor_21 are from same hypothetical_ancestor_ 22 .",
"142 and 151 are from same hypothetical_ancestor_ 23 .",
"152 and hypothetical_ancestor_23 are from same hypothetical_ancestor_ 24 .",
"150 and hypothetical_ancestor_24 are from same hypothetical_ancestor_ 25 .",
"158 and hypothetical_ancestor_25 are from same hypothetical_ancestor_ 26 .",
"hypothetical_ancestor_22 and hypothetical_ancestor_26 are from same hypothetical_ancestor_ 27 .",
"146 and hypothetical_ancestor_27 are from same hypothetical_ancestor_ 28 .",
"hypothetical_ancestor_20 and hypothetical_ancestor_28 are from same hypothetical_ancestor_ 29 .",
"144 and hypothetical_ancestor_29 are from same hypothetical_ancestor_ 30 .",
"hypothetical_ancestor_17 and hypothetical_ancestor_30 are from same hypothetical_ancestor_ 31 .",
"141 and 165 are from same hypothetical_ancestor_ 32 .",
"176 and hypothetical_ancestor_32 are from same hypothetical_ancestor_ 33 .",
"168 and hypothetical_ancestor_33 are from same hypothetical_ancestor_ 34 .",
"hypothetical_ancestor_31 and hypothetical_ancestor_34 are from same hypothetical_ancestor_ 35 .",
"148 and 174 are from same hypothetical_ancestor_ 36 .",
"hypothetical_ancestor_35 and hypothetical_ancestor_36 are from same hypothetical_ancestor_ 37 .",
"131 and 130 are from same hypothetical_ancestor_ 38 .",
"135 and 133 are from same hypothetical_ancestor_ 39 .",
"hypothetical_ancestor_38 and hypothetical_ancestor_39 are from same hypothetical_ancestor_ 40 .",
"132 and hypothetical_ancestor_40 are from same hypothetical_ancestor_ 41 .",
"134 and hypothetical_ancestor_41 are from same hypothetical_ancestor_ 42 .",
"136 and hypothetical_ancestor_42 are from same hypothetical_ancestor_ 43 .",
"427 and 428 are from same hypothetical_ancestor_ 44 .",
"429 and hypothetical_ancestor_44 are from same hypothetical_ancestor_ 45 .",
"423 and 426 are from same hypothetical_ancestor_ 46 .",
"424 and hypothetical_ancestor_46 are from same hypothetical_ancestor_ 47 .",
"425 and hypothetical_ancestor_47 are from same hypothetical_ancestor_ 48 .",
"hypothetical_ancestor_45 and hypothetical_ancestor_48 are from same hypothetical_ancestor_ 49 .",
"hypothetical_ancestor_43 and hypothetical_ancestor_49 are from same hypothetical_ancestor_ 50 .",
"138 and hypothetical_ancestor_50 are from same hypothetical_ancestor_ 51 .",
"166 and 280 are from same hypothetical_ancestor_ 52 .",
"175 and 171 are from same hypothetical_ancestor_ 53 .",
"hypothetical_ancestor_52 and hypothetical_ancestor_53 are from same hypothetical_ancestor_ 54 .",
"453 and 456 are from same hypothetical_ancestor_ 55 .",
"462 and 463 are from same hypothetical_ancestor_ 56 .",
"458 and hypothetical_ancestor_56 are from same hypothetical_ancestor_ 57 .",
"457 and 461 are from same hypothetical_ancestor_ 58 .",
"459 and hypothetical_ancestor_58 are from same hypothetical_ancestor_ 59 .",
"hypothetical_ancestor_57 and hypothetical_ancestor_59 are from same hypothetical_ancestor_ 60 .",
"454 and hypothetical_ancestor_60 are from same hypothetical_ancestor_ 61 .",
"hypothetical_ancestor_55 and hypothetical_ancestor_61 are from same hypothetical_ancestor_ 62 .",
"455 and 460 are from same hypothetical_ancestor_ 63 .",
"350 and hypothetical_ancestor_63 are from same hypothetical_ancestor_ 64 .",
"349 and 351 are from same hypothetical_ancestor_ 65 .",
"352 and hypothetical_ancestor_65 are from same hypothetical_ancestor_ 66 .",
"hypothetical_ancestor_64 and hypothetical_ancestor_66 are from same hypothetical_ancestor_ 67 .",
"330 and 334 are from same hypothetical_ancestor_ 68 .",
"331 and 335 are from same hypothetical_ancestor_ 69 .",
"332 and hypothetical_ancestor_69 are from same hypothetical_ancestor_ 70 .",
"hypothetical_ancestor_68 and hypothetical_ancestor_70 are from same hypothetical_ancestor_ 71 .",
"329 and 333 are from same hypothetical_ancestor_ 72 .",
"hypothetical_ancestor_71 and hypothetical_ancestor_72 are from same hypothetical_ancestor_ 73 .",
"hypothetical_ancestor_67 and hypothetical_ancestor_73 are from same hypothetical_ancestor_ 74 .",
"326 and 328 are from same hypothetical_ancestor_ 75 .",
"327 and hypothetical_ancestor_75 are from same hypothetical_ancestor_ 76 .",
"342 and 357 are from same hypothetical_ancestor_ 77 .",
"hypothetical_ancestor_76 and hypothetical_ancestor_77 are from same hypothetical_ancestor_ 78 .",
"343 and 344 are from same hypothetical_ancestor_ 79 .",
"345 and 347 are from same hypothetical_ancestor_ 80 .",
"346 and hypothetical_ancestor_80 are from same hypothetical_ancestor_ 81 .",
"hypothetical_ancestor_79 and hypothetical_ancestor_81 are from same hypothetical_ancestor_ 82 .",
"262 and 263 are from same hypothetical_ancestor_ 83 .",
"264 and hypothetical_ancestor_83 are from same hypothetical_ancestor_ 84 .",
"340 and hypothetical_ancestor_84 are from same hypothetical_ancestor_ 85 .",
"341 and hypothetical_ancestor_85 are from same hypothetical_ancestor_ 86 .",
"338 and 336 are from same hypothetical_ancestor_ 87 .",
"339 and hypothetical_ancestor_87 are from same hypothetical_ancestor_ 88 .",
"hypothetical_ancestor_88 and 337 are from same hypothetical_ancestor_ 89 .",
"348 and hypothetical_ancestor_89 are from same hypothetical_ancestor_ 90 .",
"358 and 359 are from same hypothetical_ancestor_ 91 .",
"353 and hypothetical_ancestor_91 are from same hypothetical_ancestor_ 92 .",
"354 and 356 are from same hypothetical_ancestor_ 93 .",
"360 and hypothetical_ancestor_93 are from same hypothetical_ancestor_ 94 .",
"hypothetical_ancestor_92 and hypothetical_ancestor_94 are from same hypothetical_ancestor_ 95 .",
"355 and hypothetical_ancestor_95 are from same hypothetical_ancestor_ 96 .",
"hypothetical_ancestor_90 and hypothetical_ancestor_96 are from same hypothetical_ancestor_ 97 .",
"hypothetical_ancestor_86 and hypothetical_ancestor_97 are from same hypothetical_ancestor_ 98 .",
"hypothetical_ancestor_82 and hypothetical_ancestor_98 are from same hypothetical_ancestor_ 99 .",
"hypothetical_ancestor_78 and hypothetical_ancestor_99 are from same hypothetical_ancestor_ 100 .",
"hypothetical_ancestor_74 and hypothetical_ancestor_100 are from same hypothetical_ancestor_ 101 .",
"hypothetical_ancestor_62 and hypothetical_ancestor_101 are from same hypothetical_ancestor_ 102 .",
"hypothetical_ancestor_54 and hypothetical_ancestor_102 are from same hypothetical_ancestor_ 103 .",
"367 and 369 are from same hypothetical_ancestor_ 104 .",
"366 and hypothetical_ancestor_104 are from same hypothetical_ancestor_ 105 .",
"170 and 173 are from same hypothetical_ancestor_ 106 .",
"365 and hypothetical_ancestor_106 are from same hypothetical_ancestor_ 107 .",
"hypothetical_ancestor_105 and hypothetical_ancestor_107 are from same hypothetical_ancestor_ 108 .",
"368 and hypothetical_ancestor_108 are from same hypothetical_ancestor_ 109 .",
"213 and 214 are from same hypothetical_ancestor_ 110 .",
"411 and 412 are from same hypothetical_ancestor_ 111 .",
"409 and 410 are from same hypothetical_ancestor_ 112 .",
"hypothetical_ancestor_111 and hypothetical_ancestor_112 are from same hypothetical_ancestor_ 113 .",
"294 and hypothetical_ancestor_113 are from same hypothetical_ancestor_ 114 .",
"452 and hypothetical_ancestor_114 are from same hypothetical_ancestor_ 115 .",
"hypothetical_ancestor_110 and hypothetical_ancestor_115 are from same hypothetical_ancestor_ 116 .",
"169 and hypothetical_ancestor_116 are from same hypothetical_ancestor_ 117 .",
"172 and hypothetical_ancestor_117 are from same hypothetical_ancestor_ 118 .",
"293 and hypothetical_ancestor_118 are from same hypothetical_ancestor_ 119 .",
"hypothetical_ancestor_109 and hypothetical_ancestor_119 are from same hypothetical_ancestor_ 120 .",
"207 and 208 are from same hypothetical_ancestor_ 121 .",
"384 and hypothetical_ancestor_121 are from same hypothetical_ancestor_ 122 .",
"404 and 184 are from same hypothetical_ancestor_ 123 .",
"292 and hypothetical_ancestor_123 are from same hypothetical_ancestor_ 124 .",
"181 and hypothetical_ancestor_124 are from same hypothetical_ancestor_ 125 .",
"395 and 397 are from same hypothetical_ancestor_ 126 .",
"396 and hypothetical_ancestor_126 are from same hypothetical_ancestor_ 127 .",
"386 and hypothetical_ancestor_127 are from same hypothetical_ancestor_ 128 .",
"221 and 223 are from same hypothetical_ancestor_ 129 .",
"267 and 215 are from same hypothetical_ancestor_ 130 .",
"hypothetical_ancestor_129 and hypothetical_ancestor_130 are from same hypothetical_ancestor_ 131 .",
"222 and hypothetical_ancestor_131 are from same hypothetical_ancestor_ 132 .",
"231 and hypothetical_ancestor_132 are from same hypothetical_ancestor_ 133 .",
"233 and hypothetical_ancestor_133 are from same hypothetical_ancestor_ 134 .",
"394 and hypothetical_ancestor_134 are from same hypothetical_ancestor_ 135 .",
"392 and hypothetical_ancestor_135 are from same hypothetical_ancestor_ 136 .",
"393 and hypothetical_ancestor_136 are from same hypothetical_ancestor_ 137 .",
"hypothetical_ancestor_128 and hypothetical_ancestor_137 are from same hypothetical_ancestor_ 138 .",
"398 and hypothetical_ancestor_138 are from same hypothetical_ancestor_ 139 .",
"391 and hypothetical_ancestor_139 are from same hypothetical_ancestor_ 140 .",
"276 and 390 are from same hypothetical_ancestor_ 141 .",
"382 and hypothetical_ancestor_141 are from same hypothetical_ancestor_ 142 .",
"381 and 383 are from same hypothetical_ancestor_ 143 .",
"415 and 413 are from same hypothetical_ancestor_ 144 .",
"414 and hypothetical_ancestor_144 are from same hypothetical_ancestor_ 145 .",
"418 and hypothetical_ancestor_145 are from same hypothetical_ancestor_ 146 .",
"385 and 399 are from same hypothetical_ancestor_ 147 .",
"400 and 402 are from same hypothetical_ancestor_ 148 .",
"401 and hypothetical_ancestor_148 are from same hypothetical_ancestor_ 149 .",
"403 and hypothetical_ancestor_149 are from same hypothetical_ancestor_ 150 .",
"389 and 388 are from same hypothetical_ancestor_ 151 .",
"hypothetical_ancestor_150 and hypothetical_ancestor_151 are from same hypothetical_ancestor_ 152 .",
"387 and hypothetical_ancestor_152 are from same hypothetical_ancestor_ 153 .",
"hypothetical_ancestor_147 and hypothetical_ancestor_153 are from same hypothetical_ancestor_ 154 .",
"hypothetical_ancestor_146 and hypothetical_ancestor_154 are from same hypothetical_ancestor_ 155 .",
"hypothetical_ancestor_143 and hypothetical_ancestor_155 are from same hypothetical_ancestor_ 156 .",
"279 and hypothetical_ancestor_156 are from same hypothetical_ancestor_ 157 .",
"hypothetical_ancestor_142 and hypothetical_ancestor_157 are from same hypothetical_ancestor_ 158 .",
"hypothetical_ancestor_140 and hypothetical_ancestor_158 are from same hypothetical_ancestor_ 159 .",
"268 and 273 are from same hypothetical_ancestor_ 160 .",
"274 and hypothetical_ancestor_160 are from same hypothetical_ancestor_ 161 .",
"216 and 219 are from same hypothetical_ancestor_ 162 .",
"hypothetical_ancestor_162 and 217 are from same hypothetical_ancestor_ 163 .",
"218 and hypothetical_ancestor_163 are from same hypothetical_ancestor_ 164 .",
"hypothetical_ancestor_161 and hypothetical_ancestor_164 are from same hypothetical_ancestor_ 165 .",
"224 and 228 are from same hypothetical_ancestor_ 166 .",
"hypothetical_ancestor_166 and 226 are from same hypothetical_ancestor_ 167 .",
"hypothetical_ancestor_167 and 225 are from same hypothetical_ancestor_ 168 .",
"227 and hypothetical_ancestor_168 are from same hypothetical_ancestor_ 169 .",
"277 and hypothetical_ancestor_169 are from same hypothetical_ancestor_ 170 .",
"370 and 371 are from same hypothetical_ancestor_ 171 .",
"372 and 373 are from same hypothetical_ancestor_ 172 .",
"hypothetical_ancestor_171 and hypothetical_ancestor_172 are from same hypothetical_ancestor_ 173 .",
"374 and hypothetical_ancestor_173 are from same hypothetical_ancestor_ 174 .",
"283 and 288 are from same hypothetical_ancestor_ 175 .",
"286 and hypothetical_ancestor_175 are from same hypothetical_ancestor_ 176 .",
"284 and hypothetical_ancestor_176 are from same hypothetical_ancestor_ 177 .",
"253 and hypothetical_ancestor_177 are from same hypothetical_ancestor_ 178 .",
"287 and hypothetical_ancestor_178 are from same hypothetical_ancestor_ 179 .",
"290 and hypothetical_ancestor_179 are from same hypothetical_ancestor_ 180 .",
"285 and hypothetical_ancestor_180 are from same hypothetical_ancestor_ 181 .",
"289 and hypothetical_ancestor_181 are from same hypothetical_ancestor_ 182 .",
"266 and hypothetical_ancestor_182 are from same hypothetical_ancestor_ 183 .",
"255 and 256 are from same hypothetical_ancestor_ 184 .",
"252 and hypothetical_ancestor_184 are from same hypothetical_ancestor_ 185 .",
"248 and 249 are from same hypothetical_ancestor_ 186 .",
"271 and hypothetical_ancestor_186 are from same hypothetical_ancestor_ 187 .",
"241 and hypothetical_ancestor_187 are from same hypothetical_ancestor_ 188 .",
"247 and hypothetical_ancestor_188 are from same hypothetical_ancestor_ 189 .",
"245 and hypothetical_ancestor_189 are from same hypothetical_ancestor_ 190 .",
"278 and hypothetical_ancestor_190 are from same hypothetical_ancestor_ 191 .",
"246 and hypothetical_ancestor_191 are from same hypothetical_ancestor_ 192 .",
"275 and hypothetical_ancestor_192 are from same hypothetical_ancestor_ 193 .",
"250 and hypothetical_ancestor_193 are from same hypothetical_ancestor_ 194 .",
"254 and hypothetical_ancestor_194 are from same hypothetical_ancestor_ 195 .",
"hypothetical_ancestor_185 and hypothetical_ancestor_195 are from same hypothetical_ancestor_ 196 .",
"hypothetical_ancestor_183 and hypothetical_ancestor_196 are from same hypothetical_ancestor_ 197 .",
"hypothetical_ancestor_174 and hypothetical_ancestor_197 are from same hypothetical_ancestor_ 198 .",
"291 and hypothetical_ancestor_198 are from same hypothetical_ancestor_ 199 .",
"203 and hypothetical_ancestor_199 are from same hypothetical_ancestor_ 200 .",
"281 and 282 are from same hypothetical_ancestor_ 201 .",
"212 and 211 are from same hypothetical_ancestor_ 202 .",
"210 and hypothetical_ancestor_202 are from same hypothetical_ancestor_ 203 .",
"hypothetical_ancestor_201 and hypothetical_ancestor_203 are from same hypothetical_ancestor_ 204 .",
"420 and 421 are from same hypothetical_ancestor_ 205 .",
"417 and 416 are from same hypothetical_ancestor_ 206 .",
"422 and hypothetical_ancestor_206 are from same hypothetical_ancestor_ 207 .",
"419 and hypothetical_ancestor_207 are from same hypothetical_ancestor_ 208 .",
"hypothetical_ancestor_205 and hypothetical_ancestor_208 are from same hypothetical_ancestor_ 209 .",
"hypothetical_ancestor_204 and hypothetical_ancestor_209 are from same hypothetical_ancestor_ 210 .",
"251 and 272 are from same hypothetical_ancestor_ 211 .",
"243 and 261 are from same hypothetical_ancestor_ 212 .",
"265 and 377 are from same hypothetical_ancestor_ 213 .",
"258 and 260 are from same hypothetical_ancestor_ 214 .",
"257 and hypothetical_ancestor_214 are from same hypothetical_ancestor_ 215 .",
"376 and 375 are from same hypothetical_ancestor_ 216 .",
"hypothetical_ancestor_215 and hypothetical_ancestor_216 are from same hypothetical_ancestor_ 217 .",
"hypothetical_ancestor_213 and hypothetical_ancestor_217 are from same hypothetical_ancestor_ 218 .",
"hypothetical_ancestor_212 and hypothetical_ancestor_218 are from same hypothetical_ancestor_ 219 .",
"hypothetical_ancestor_211 and hypothetical_ancestor_219 are from same hypothetical_ancestor_ 220 .",
"209 and 230 are from same hypothetical_ancestor_ 221 .",
"269 and 232 are from same hypothetical_ancestor_ 222 .",
"hypothetical_ancestor_221 and hypothetical_ancestor_222 are from same hypothetical_ancestor_ 223 .",
"229 and 238 are from same hypothetical_ancestor_ 224 .",
"234 and 242 are from same hypothetical_ancestor_ 225 .",
"236 and hypothetical_ancestor_225 are from same hypothetical_ancestor_ 226 .",
"hypothetical_ancestor_224 and hypothetical_ancestor_226 are from same hypothetical_ancestor_ 227 .",
"hypothetical_ancestor_223 and hypothetical_ancestor_227 are from same hypothetical_ancestor_ 228 .",
"237 and hypothetical_ancestor_228 are from same hypothetical_ancestor_ 229 .",
"239 and hypothetical_ancestor_229 are from same hypothetical_ancestor_ 230 .",
"244 and hypothetical_ancestor_230 are from same hypothetical_ancestor_ 231 .",
"235 and hypothetical_ancestor_231 are from same hypothetical_ancestor_ 232 .",
"259 and 472 are from same hypothetical_ancestor_ 233 .",
"hypothetical_ancestor_232 and hypothetical_ancestor_233 are from same hypothetical_ancestor_ 234 .",
"hypothetical_ancestor_234 and 240 are from same hypothetical_ancestor_ 235 .",
"hypothetical_ancestor_220 and hypothetical_ancestor_235 are from same hypothetical_ancestor_ 236 .",
"hypothetical_ancestor_210 and hypothetical_ancestor_236 are from same hypothetical_ancestor_ 237 .",
"hypothetical_ancestor_200 and hypothetical_ancestor_237 are from same hypothetical_ancestor_ 238 .",
"hypothetical_ancestor_170 and hypothetical_ancestor_238 are from same hypothetical_ancestor_ 239 .",
"hypothetical_ancestor_165 and hypothetical_ancestor_239 are from same hypothetical_ancestor_ 240 .",
"hypothetical_ancestor_159 and hypothetical_ancestor_240 are from same hypothetical_ancestor_ 241 .",
"270 and hypothetical_ancestor_241 are from same hypothetical_ancestor_ 242 .",
"220 and hypothetical_ancestor_242 are from same hypothetical_ancestor_ 243 .",
"hypothetical_ancestor_125 and hypothetical_ancestor_243 are from same hypothetical_ancestor_ 244 .",
"hypothetical_ancestor_122 and hypothetical_ancestor_244 are from same hypothetical_ancestor_ 245 .",
"hypothetical_ancestor_120 and hypothetical_ancestor_245 are from same hypothetical_ancestor_ 246 .",
"hypothetical_ancestor_103 and hypothetical_ancestor_246 are from same hypothetical_ancestor_ 247 .",
"hypothetical_ancestor_51 and hypothetical_ancestor_247 are from same hypothetical_ancestor_ 248 .",
"408 and hypothetical_ancestor_248 are from same hypothetical_ancestor_ 249 .",
"hypothetical_ancestor_37 and hypothetical_ancestor_249 are from same hypothetical_ancestor_ 250 .",
"hypothetical_ancestor_16 and hypothetical_ancestor_250 are from same hypothetical_ancestor_ 251 .",
"129 and hypothetical_ancestor_251 are from same hypothetical_ancestor_ 252 .",
"hypothetical_ancestor_9 and hypothetical_ancestor_252 are from same hypothetical_ancestor_ 253 .",
"128 and hypothetical_ancestor_253 are from same hypothetical_ancestor_ 254 .",
"321 and 324 are from same hypothetical_ancestor_ 255 .",
"325 and hypothetical_ancestor_255 are from same hypothetical_ancestor_ 256 .",
"322 and hypothetical_ancestor_256 are from same hypothetical_ancestor_ 257 .",
"323 and hypothetical_ancestor_257 are from same hypothetical_ancestor_ 258 .",
"476 and 473 are from same hypothetical_ancestor_ 259 .",
"160 and hypothetical_ancestor_259 are from same hypothetical_ancestor_ 260 .",
"475 and 474 are from same hypothetical_ancestor_ 261 .",
"185 and hypothetical_ancestor_261 are from same hypothetical_ancestor_ 262 .",
"hypothetical_ancestor_260 and hypothetical_ancestor_262 are from same hypothetical_ancestor_ 263 .",
"hypothetical_ancestor_258 and hypothetical_ancestor_263 are from same hypothetical_ancestor_ 264 .",
"310 and 313 are from same hypothetical_ancestor_ 265 .",
"315 and 320 are from same hypothetical_ancestor_ 266 .",
"316 and 317 are from same hypothetical_ancestor_ 267 .",
"hypothetical_ancestor_266 and hypothetical_ancestor_267 are from same hypothetical_ancestor_ 268 .",
"314 and hypothetical_ancestor_268 are from same hypothetical_ancestor_ 269 .",
"309 and hypothetical_ancestor_269 are from same hypothetical_ancestor_ 270 .",
"hypothetical_ancestor_265 and hypothetical_ancestor_270 are from same hypothetical_ancestor_ 271 .",
"301 and 306 are from same hypothetical_ancestor_ 272 .",
"298 and hypothetical_ancestor_272 are from same hypothetical_ancestor_ 273 .",
"300 and hypothetical_ancestor_273 are from same hypothetical_ancestor_ 274 .",
"311 and hypothetical_ancestor_274 are from same hypothetical_ancestor_ 275 .",
"303 and hypothetical_ancestor_275 are from same hypothetical_ancestor_ 276 .",
"295 and hypothetical_ancestor_276 are from same hypothetical_ancestor_ 277 .",
"296 and hypothetical_ancestor_277 are from same hypothetical_ancestor_ 278 .",
"305 and 318 are from same hypothetical_ancestor_ 279 .",
"297 and hypothetical_ancestor_279 are from same hypothetical_ancestor_ 280 .",
"304 and hypothetical_ancestor_280 are from same hypothetical_ancestor_ 281 .",
"302 and 307 are from same hypothetical_ancestor_ 282 .",
"299 and hypothetical_ancestor_282 are from same hypothetical_ancestor_ 283 .",
"312 and hypothetical_ancestor_283 are from same hypothetical_ancestor_ 284 .",
"hypothetical_ancestor_281 and hypothetical_ancestor_284 are from same hypothetical_ancestor_ 285 .",
"308 and hypothetical_ancestor_285 are from same hypothetical_ancestor_ 286 .",
"319 and hypothetical_ancestor_286 are from same hypothetical_ancestor_ 287 .",
"hypothetical_ancestor_278 and hypothetical_ancestor_287 are from same hypothetical_ancestor_ 288 .",
"hypothetical_ancestor_271 and hypothetical_ancestor_288 are from same hypothetical_ancestor_ 289 .",
"hypothetical_ancestor_264 and hypothetical_ancestor_289 are from same hypothetical_ancestor_ 290 .",
"191 and 198 are from same hypothetical_ancestor_ 291 .",
"190 and 194 are from same hypothetical_ancestor_ 292 .",
"189 and 192 are from same hypothetical_ancestor_ 293 .",
"hypothetical_ancestor_292 and hypothetical_ancestor_293 are from same hypothetical_ancestor_ 294 .",
"196 and 197 are from same hypothetical_ancestor_ 295 .",
"195 and 201 are from same hypothetical_ancestor_ 296 .",
"202 and hypothetical_ancestor_296 are from same hypothetical_ancestor_ 297 .",
"hypothetical_ancestor_295 and hypothetical_ancestor_297 are from same hypothetical_ancestor_ 298 .",
"200 and hypothetical_ancestor_298 are from same hypothetical_ancestor_ 299 .",
"hypothetical_ancestor_294 and hypothetical_ancestor_299 are from same hypothetical_ancestor_ 300 .",
"193 and hypothetical_ancestor_300 are from same hypothetical_ancestor_ 301 .",
"hypothetical_ancestor_291 and hypothetical_ancestor_301 are from same hypothetical_ancestor_ 302 .",
"199 and hypothetical_ancestor_302 are from same hypothetical_ancestor_ 303 .",
"431 and 432 are from same hypothetical_ancestor_ 304 .",
"436 and 447 are from same hypothetical_ancestor_ 305 .",
"439 and 442 are from same hypothetical_ancestor_ 306 .",
"435 and hypothetical_ancestor_306 are from same hypothetical_ancestor_ 307 .",
"448 and hypothetical_ancestor_307 are from same hypothetical_ancestor_ 308 .",
"hypothetical_ancestor_305 and hypothetical_ancestor_308 are from same hypothetical_ancestor_ 309 .",
"433 and 441 are from same hypothetical_ancestor_ 310 .",
"437 and 440 are from same hypothetical_ancestor_ 311 .",
"443 and 449 are from same hypothetical_ancestor_ 312 .",
"450 and hypothetical_ancestor_312 are from same hypothetical_ancestor_ 313 .",
"445 and 446 are from same hypothetical_ancestor_ 314 .",
"451 and hypothetical_ancestor_314 are from same hypothetical_ancestor_ 315 .",
"438 and hypothetical_ancestor_315 are from same hypothetical_ancestor_ 316 .",
"hypothetical_ancestor_313 and hypothetical_ancestor_316 are from same hypothetical_ancestor_ 317 .",
"444 and hypothetical_ancestor_317 are from same hypothetical_ancestor_ 318 .",
"hypothetical_ancestor_311 and hypothetical_ancestor_318 are from same hypothetical_ancestor_ 319 .",
"hypothetical_ancestor_310 and hypothetical_ancestor_319 are from same hypothetical_ancestor_ 320 .",
"434 and hypothetical_ancestor_320 are from same hypothetical_ancestor_ 321 .",
"hypothetical_ancestor_309 and hypothetical_ancestor_321 are from same hypothetical_ancestor_ 322 .",
"hypothetical_ancestor_304 and hypothetical_ancestor_322 are from same hypothetical_ancestor_ 323 .",
"hypothetical_ancestor_303 and hypothetical_ancestor_323 are from same hypothetical_ancestor_ 324 .",
"hypothetical_ancestor_290 and hypothetical_ancestor_324 are from same hypothetical_ancestor_ 325 .",
"137 and 167 are from same hypothetical_ancestor_ 326 .",
"464 and 465 are from same hypothetical_ancestor_ 327 .",
"466 and 470 are from same hypothetical_ancestor_ 328 .",
"467 and hypothetical_ancestor_328 are from same hypothetical_ancestor_ 329 .",
"469 and hypothetical_ancestor_329 are from same hypothetical_ancestor_ 330 .",
"468 and hypothetical_ancestor_330 are from same hypothetical_ancestor_ 331 .",
"hypothetical_ancestor_327 and hypothetical_ancestor_331 are from same hypothetical_ancestor_ 332 .",
"182 and 183 are from same hypothetical_ancestor_ 333 .",
"120 and hypothetical_ancestor_333 are from same hypothetical_ancestor_ 334 .",
"112 and 117 are from same hypothetical_ancestor_ 335 .",
"113 and 116 are from same hypothetical_ancestor_ 336 .",
"114 and 118 are from same hypothetical_ancestor_ 337 .",
"hypothetical_ancestor_336 and hypothetical_ancestor_337 are from same hypothetical_ancestor_ 338 .",
"hypothetical_ancestor_335 and hypothetical_ancestor_338 are from same hypothetical_ancestor_ 339 .",
"115 and hypothetical_ancestor_339 are from same hypothetical_ancestor_ 340 .",
"123 and 125 are from same hypothetical_ancestor_ 341 .",
"124 and hypothetical_ancestor_341 are from same hypothetical_ancestor_ 342 .",
"126 and hypothetical_ancestor_342 are from same hypothetical_ancestor_ 343 .",
"119 and hypothetical_ancestor_343 are from same hypothetical_ancestor_ 344 .",
"121 and hypothetical_ancestor_344 are from same hypothetical_ancestor_ 345 .",
"hypothetical_ancestor_340 and hypothetical_ancestor_345 are from same hypothetical_ancestor_ 346 .",
"157 and hypothetical_ancestor_346 are from same hypothetical_ancestor_ 347 .",
"hypothetical_ancestor_334 and hypothetical_ancestor_347 are from same hypothetical_ancestor_ 348 .",
"204 and 205 are from same hypothetical_ancestor_ 349 .",
"364 and 206 are from same hypothetical_ancestor_ 350 .",
"407 and 405 are from same hypothetical_ancestor_ 351 .",
"406 and hypothetical_ancestor_351 are from same hypothetical_ancestor_ 352 .",
"hypothetical_ancestor_350 and hypothetical_ancestor_352 are from same hypothetical_ancestor_ 353 .",
"hypothetical_ancestor_349 and hypothetical_ancestor_353 are from same hypothetical_ancestor_ 354 .",
"122 and hypothetical_ancestor_354 are from same hypothetical_ancestor_ 355 .",
"105 and 100 are from same hypothetical_ancestor_ 356 .",
"102 and hypothetical_ancestor_356 are from same hypothetical_ancestor_ 357 .",
"92 and hypothetical_ancestor_357 are from same hypothetical_ancestor_ 358 .",
"88 and 101 are from same hypothetical_ancestor_ 359 .",
"75 and 85 are from same hypothetical_ancestor_ 360 .",
"82 and 106 are from same hypothetical_ancestor_ 361 .",
"hypothetical_ancestor_360 and hypothetical_ancestor_361 are from same hypothetical_ancestor_ 362 .",
"96 and hypothetical_ancestor_362 are from same hypothetical_ancestor_ 363 .",
"83 and 94 are from same hypothetical_ancestor_ 364 .",
"97 and 99 are from same hypothetical_ancestor_ 365 .",
"103 and 110 are from same hypothetical_ancestor_ 366 .",
"hypothetical_ancestor_365 and hypothetical_ancestor_366 are from same hypothetical_ancestor_ 367 .",
"104 and hypothetical_ancestor_367 are from same hypothetical_ancestor_ 368 .",
"91 and hypothetical_ancestor_368 are from same hypothetical_ancestor_ 369 .",
"hypothetical_ancestor_364 and hypothetical_ancestor_369 are from same hypothetical_ancestor_ 370 .",
"hypothetical_ancestor_363 and hypothetical_ancestor_370 are from same hypothetical_ancestor_ 371 .",
"109 and 84 are from same hypothetical_ancestor_ 372 .",
"98 and hypothetical_ancestor_372 are from same hypothetical_ancestor_ 373 .",
"89 and hypothetical_ancestor_373 are from same hypothetical_ancestor_ 374 .",
"86 and 111 are from same hypothetical_ancestor_ 375 .",
"90 and hypothetical_ancestor_375 are from same hypothetical_ancestor_ 376 .",
"95 and 107 are from same hypothetical_ancestor_ 377 .",
"108 and hypothetical_ancestor_377 are from same hypothetical_ancestor_ 378 .",
"93 and hypothetical_ancestor_378 are from same hypothetical_ancestor_ 379 .",
"hypothetical_ancestor_379 and 76 are from same hypothetical_ancestor_ 380 .",
"hypothetical_ancestor_376 and hypothetical_ancestor_380 are from same hypothetical_ancestor_ 381 .",
"hypothetical_ancestor_374 and hypothetical_ancestor_381 are from same hypothetical_ancestor_ 382 .",
"87 and hypothetical_ancestor_382 are from same hypothetical_ancestor_ 383 .",
"hypothetical_ancestor_371 and hypothetical_ancestor_383 are from same hypothetical_ancestor_ 384 .",
"hypothetical_ancestor_359 and hypothetical_ancestor_384 are from same hypothetical_ancestor_ 385 .",
"hypothetical_ancestor_358 and hypothetical_ancestor_385 are from same hypothetical_ancestor_ 386 .",
"80 and 79 are from same hypothetical_ancestor_ 387 .",
"78 and hypothetical_ancestor_387 are from same hypothetical_ancestor_ 388 .",
"81 and hypothetical_ancestor_388 are from same hypothetical_ancestor_ 389 .",
"69 and 33 are from same hypothetical_ancestor_ 390 .",
"hypothetical_ancestor_390 and 19 are from same hypothetical_ancestor_ 391 .",
"20 and 67 are from same hypothetical_ancestor_ 392 .",
"1 and 22 are from same hypothetical_ancestor_ 393 .",
"12 and 52 are from same hypothetical_ancestor_ 394 .",
"37 and 50 are from same hypothetical_ancestor_ 395 .",
"2 and 58 are from same hypothetical_ancestor_ 396 .",
"36 and 16 are from same hypothetical_ancestor_ 397 .",
"23 and 61 are from same hypothetical_ancestor_ 398 .",
"hypothetical_ancestor_397 and hypothetical_ancestor_398 are from same hypothetical_ancestor_ 399 .",
"25 and 30 are from same hypothetical_ancestor_ 400 .",
"hypothetical_ancestor_400 and 24 are from same hypothetical_ancestor_ 401 .",
"60 and hypothetical_ancestor_401 are from same hypothetical_ancestor_ 402 .",
"57 and 48 are from same hypothetical_ancestor_ 403 .",
"hypothetical_ancestor_403 and 17 are from same hypothetical_ancestor_ 404 .",
"hypothetical_ancestor_404 and 47 are from same hypothetical_ancestor_ 405 .",
"hypothetical_ancestor_402 and hypothetical_ancestor_405 are from same hypothetical_ancestor_ 406 .",
"32 and 44 are from same hypothetical_ancestor_ 407 .",
"14 and hypothetical_ancestor_407 are from same hypothetical_ancestor_ 408 .",
"4 and 31 are from same hypothetical_ancestor_ 409 .",
"hypothetical_ancestor_408 and hypothetical_ancestor_409 are from same hypothetical_ancestor_ 410 .",
"45 and 66 are from same hypothetical_ancestor_ 411 .",
"hypothetical_ancestor_410 and hypothetical_ancestor_411 are from same hypothetical_ancestor_ 412 .",
"hypothetical_ancestor_406 and hypothetical_ancestor_412 are from same hypothetical_ancestor_ 413 .",
"hypothetical_ancestor_399 and hypothetical_ancestor_413 are from same hypothetical_ancestor_ 414 .",
"18 and 63 are from same hypothetical_ancestor_ 415 .",
"7 and 41 are from same hypothetical_ancestor_ 416 .",
"65 and 70 are from same hypothetical_ancestor_ 417 .",
"10 and hypothetical_ancestor_417 are from same hypothetical_ancestor_ 418 .",
"15 and 74 are from same hypothetical_ancestor_ 419 .",
"3 and hypothetical_ancestor_419 are from same hypothetical_ancestor_ 420 .",
"hypothetical_ancestor_420 and 64 are from same hypothetical_ancestor_ 421 .",
"hypothetical_ancestor_418 and hypothetical_ancestor_421 are from same hypothetical_ancestor_ 422 .",
"hypothetical_ancestor_416 and hypothetical_ancestor_422 are from same hypothetical_ancestor_ 423 .",
"hypothetical_ancestor_415 and hypothetical_ancestor_423 are from same hypothetical_ancestor_ 424 .",
"9 and 27 are from same hypothetical_ancestor_ 425 .",
"hypothetical_ancestor_425 and 8 are from same hypothetical_ancestor_ 426 .",
"29 and 55 are from same hypothetical_ancestor_ 427 .",
"hypothetical_ancestor_426 and hypothetical_ancestor_427 are from same hypothetical_ancestor_ 428 .",
"hypothetical_ancestor_428 and 28 are from same hypothetical_ancestor_ 429 .",
"46 and 62 are from same hypothetical_ancestor_ 430 .",
"5 and 56 are from same hypothetical_ancestor_ 431 .",
"26 and 38 are from same hypothetical_ancestor_ 432 .",
"hypothetical_ancestor_431 and hypothetical_ancestor_432 are from same hypothetical_ancestor_ 433 .",
"11 and 43 are from same hypothetical_ancestor_ 434 .",
"35 and 51 are from same hypothetical_ancestor_ 435 .",
"71 and hypothetical_ancestor_435 are from same hypothetical_ancestor_ 436 .",
"hypothetical_ancestor_434 and hypothetical_ancestor_436 are from same hypothetical_ancestor_ 437 .",
"hypothetical_ancestor_433 and hypothetical_ancestor_437 are from same hypothetical_ancestor_ 438 .",
"49 and hypothetical_ancestor_438 are from same hypothetical_ancestor_ 439 .",
"hypothetical_ancestor_430 and hypothetical_ancestor_439 are from same hypothetical_ancestor_ 440 .",
"hypothetical_ancestor_429 and hypothetical_ancestor_440 are from same hypothetical_ancestor_ 441 .",
"hypothetical_ancestor_424 and hypothetical_ancestor_441 are from same hypothetical_ancestor_ 442 .",
"39 and 72 are from same hypothetical_ancestor_ 443 .",
"hypothetical_ancestor_443 and 53 are from same hypothetical_ancestor_ 444 .",
"54 and 21 are from same hypothetical_ancestor_ 445 .",
"68 and hypothetical_ancestor_445 are from same hypothetical_ancestor_ 446 .",
"hypothetical_ancestor_446 and 73 are from same hypothetical_ancestor_ 447 .",
"hypothetical_ancestor_444 and hypothetical_ancestor_447 are from same hypothetical_ancestor_ 448 .",
"13 and 42 are from same hypothetical_ancestor_ 449 .",
"hypothetical_ancestor_449 and 40 are from same hypothetical_ancestor_ 450 .",
"hypothetical_ancestor_448 and hypothetical_ancestor_450 are from same hypothetical_ancestor_ 451 .",
"34 and 59 are from same hypothetical_ancestor_ 452 .",
"hypothetical_ancestor_451 and hypothetical_ancestor_452 are from same hypothetical_ancestor_ 453 .",
"hypothetical_ancestor_442 and hypothetical_ancestor_453 are from same hypothetical_ancestor_ 454 .",
"hypothetical_ancestor_414 and hypothetical_ancestor_454 are from same hypothetical_ancestor_ 455 .",
"hypothetical_ancestor_396 and hypothetical_ancestor_455 are from same hypothetical_ancestor_ 456 .",
"hypothetical_ancestor_395 and hypothetical_ancestor_456 are from same hypothetical_ancestor_ 457 .",
"hypothetical_ancestor_394 and hypothetical_ancestor_457 are from same hypothetical_ancestor_ 458 .",
"hypothetical_ancestor_393 and hypothetical_ancestor_458 are from same hypothetical_ancestor_ 459 .",
"hypothetical_ancestor_392 and hypothetical_ancestor_459 are from same hypothetical_ancestor_ 460 .",
"hypothetical_ancestor_391 and hypothetical_ancestor_460 are from same hypothetical_ancestor_ 461 .",
"6 and hypothetical_ancestor_461 are from same hypothetical_ancestor_ 462 .",
"hypothetical_ancestor_389 and hypothetical_ancestor_462 are from same hypothetical_ancestor_ 463 .",
"hypothetical_ancestor_386 and hypothetical_ancestor_463 are from same hypothetical_ancestor_ 464 .",
"77 and hypothetical_ancestor_464 are from same hypothetical_ancestor_ 465 .",
"430 and hypothetical_ancestor_465 are from same hypothetical_ancestor_ 466 .",
"hypothetical_ancestor_355 and hypothetical_ancestor_466 are from same hypothetical_ancestor_ 467 .",
"hypothetical_ancestor_348 and hypothetical_ancestor_467 are from same hypothetical_ancestor_ 468 .",
"hypothetical_ancestor_332 and hypothetical_ancestor_468 are from same hypothetical_ancestor_ 469 .",
"hypothetical_ancestor_326 and hypothetical_ancestor_469 are from same hypothetical_ancestor_ 470 .",
"hypothetical_ancestor_325 and hypothetical_ancestor_470 are from same hypothetical_ancestor_ 471 .",
"363 and hypothetical_ancestor_471 are from same hypothetical_ancestor_ 472 .",
"hypothetical_ancestor_254 and hypothetical_ancestor_472 are from same hypothetical_ancestor_ 473 .",
"hypothetical_ancestor_5 and hypothetical_ancestor_473 are from same hypothetical_ancestor_ 474 .",
"hypothetical_ancestor_1 and hypothetical_ancestor_474 are from same hypothetical_ancestor_ 475 ."
]

# list of child-parent questions
# questions = [
#     ("Who is the parent of GVA4_Java?", "hypothetical_ancestor_"),
#     ("Who are the children of hypothetical_ancestor_4?", "GVA1_Malay_Penninsula"),
#     ("Who is the parent of hypothetical_ancestor_5?", "hypothetical_ancestor_")
# ]

questions = [
    ("Who is the common ancestor of 187 and 188", "hypothetical_ancestor_ 1"),
    ("Who is the common ancestor of 379 and 380", "hypothetical_ancestor_ 2"),
    ("Who is the common ancestor of 361 and 362", "hypothetical_ancestor_ 4"),
    ("Who is the common ancestor of 163 and hypothetical_ancestor_ 6", "hypothetical_ancestor_ 7"),
    ("Who is the common ancestor of 127 and hypothetical_ancestor_ 10", "hypothetical_ancestor_ 11"),
    ("Who is the common ancestor of 143 and 471", "hypothetical_ancestor_ 18"),
    ("Who is the common ancestor of 152 and hypothetical_ancestor_23", "hypothetical_ancestor_ 24"),
    ("Who is the common ancestor of 132 and hypothetical_ancestor_40", "hypothetical_ancestor_ 41"),
    ("Who is the common ancestor of 175 and 171", "hypothetical_ancestor_ 53"),
    ("Who is the common ancestor of 298 and hypothetical_ancestor_272", "hypothetical_ancestor_ 273"),
    ("Who is the common ancestor of hypothetical_ancestor_350 and hypothetical_ancestor_352", "hypothetical_ancestor_ 353"),
    ("Who are the children of hypothetical_ancestor_ 66", "352 and hypothetical_ancestor_65"),
    ("Who are the children of hypothetical_ancestor_ 206", "417 and 416"),
    ("Who are the children of hypothetical_ancestor_ 110", "213 and 214"),
    ("Who are the children of hypothetical_ancestor_ 167", "hypothetical_ancestor_166 and 226"),
    ("Who are the children of hypothetical_ancestor_ 417", "65 and 70"),
    ("Who are the children of hypothetical_ancestor_ 335", "112 and 117"),
    ("Who is the parent of 431", "hypothetical_ancestor_ 304"),
    ("Who is the parent of hypothetical_ancestor_466", "hypothetical_ancestor_ 467"),
    ("Who is the parent of 71", "hypothetical_ancestor_ 436")
]

# generate answers and calculate F1 score
true_labels = []
predicted_labels = []
for question in questions:
    true_labels.append(question[1])
    answer = generate_answer(question[0], ' '.join(sentences))
    print(f"Q: {question[0]}")
    print(f"A: {answer}")
    predicted_labels.append(answer.strip())

y_true = true_labels
y_pred = predicted_labels
f1 = f1_score(y_true, y_pred, average="weighted")
precision = precision_score(y_true, y_pred, average="weighted")
recall = recall_score(y_true, y_pred, average="weighted")
#exact_match = int(y_true == y_pred)
exact_match = 0
n = len(y_true)
for i in range(n):
  if y_true[i]==y_pred[i]:
    exact_match = exact_match + 1

# Print the output and metrics
print("Evaluation Metrics:")
print("F1-score:", f1)
print("Precision:", precision)
print("Recall:", recall)
print("Exact Match:", exact_match)
